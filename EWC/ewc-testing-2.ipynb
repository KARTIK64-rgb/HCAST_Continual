# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fgvc-aircraft/val.csv
# /kaggle/input/fgvc-aircraft/train.csv
# /kaggle/input/fgvc-aircraft/test.csv
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/example_evaluation.m
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/vl_pr.m
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/evaluation.m
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/README.md
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/vl_roc.m
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/vl_argparse.m
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/README.html
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/vl_tpfp.m
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_manufacturer_train.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_variant_val.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_train.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/variants.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_box.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_family_test.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_family_val.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_manufacturer_trainval.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/families.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/manufacturers.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_variant_trainval.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_manufacturer_val.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_val.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_manufacturer_test.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_variant_test.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_family_trainval.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_family_train.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_test.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_variant_train.txt
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2042721.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1535181.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2245660.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1013082.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1157334.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1385706.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1534376.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0576246.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1146069.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1889566.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1445618.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1327284.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0842128.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2195779.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0103331.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2105219.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0939509.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0727631.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0773044.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2069535.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1222195.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0951126.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0182724.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2005735.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0118429.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0192881.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1193030.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0577856.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0986161.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0109449.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0967862.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0539186.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0465507.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283304.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0550468.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1267455.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1349345.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1544222.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1374624.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1121194.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1503757.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1757004.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1620007.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0822062.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0063838.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302786.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0987802.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2192122.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0888030.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0768399.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0662343.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1338873.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2130085.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1323009.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0880570.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1876024.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1194330.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2118873.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0936117.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1019430.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1831582.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1193586.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1147907.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1016538.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1008872.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0405438.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0476348.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1548486.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0517105.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0525265.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2233055.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1985184.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0403850.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0312421.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1749186.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0810604.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0751325.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0903776.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1158577.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0552041.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1539459.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1126597.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1215240.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0313721.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0993951.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0957980.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1213050.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1838535.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1878591.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0733747.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1113208.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2175372.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0136480.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1427673.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0563774.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2258768.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0074246.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1376737.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1364623.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1932450.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1985096.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0869722.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0548186.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0914475.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2111679.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1232268.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0907419.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1050684.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0836147.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1241521.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0123337.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1522867.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0704269.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2127975.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1767577.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1508811.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0383679.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0757186.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2206145.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2039047.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2258769.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0939577.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1425173.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2123149.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0091362.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1117081.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1702899.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1124594.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1398764.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1772221.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1017179.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1606745.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1569052.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1895995.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2193787.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259152.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1412918.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0136185.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1269006.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1931897.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1316606.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0845910.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0335182.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0574359.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2230107.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1157371.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1271556.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0466917.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0918184.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0606123.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1548444.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0218812.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2145444.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1753659.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1401605.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1385344.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0522975.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0298309.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2084967.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1303460.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2168926.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1053502.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1285957.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0523168.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0771762.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1883790.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1300481.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0917396.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1110779.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1085158.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239584.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1191372.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0525849.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1218624.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0063435.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1726039.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0593168.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1785533.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2168374.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0457892.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1053532.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255844.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0338174.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2117298.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1088602.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0097119.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312536.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0339425.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0396537.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1146631.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1215875.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1270714.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1862134.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1376815.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0197342.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1379290.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1551125.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1398071.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0788951.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2202486.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1790501.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0181715.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1852244.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0257282.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0344066.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1218924.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1329269.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1356931.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0286125.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1921950.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1459176.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1062014.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1203397.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1558572.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0193711.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0447439.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0177659.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0958089.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1943354.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2098098.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2088351.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1031454.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0306188.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1768872.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1341837.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1237633.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1486858.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1634276.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2021865.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0576232.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0984284.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1667002.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1776868.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0993482.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1718621.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1627449.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2137086.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2228410.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0761153.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243380.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1807114.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0582365.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0744300.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1463774.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2200431.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1188170.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1474933.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0048340.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1726550.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1000026.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1461218.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0090861.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1122822.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0570728.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0979868.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1176955.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0909665.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1977817.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0187248.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0959265.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2241569.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0109630.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0944995.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0428662.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2183378.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1893205.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0944247.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1194421.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0083150.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0988468.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1773981.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0939503.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2072464.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1182656.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0296011.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0239592.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1818832.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0127058.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0572861.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1535841.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0195003.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1004743.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1418848.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0062655.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1364591.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1148895.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0457857.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1906657.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1373249.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1940190.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1741519.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1426565.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0719790.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0606131.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0923888.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1222169.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1899261.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1133885.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1386248.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1228462.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0497885.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0675845.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2090708.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1401606.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0885092.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2180164.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0974734.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1503763.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0758787.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1723103.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1879115.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1658586.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1202520.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1062306.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0924092.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0746098.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0329378.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0805499.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2218546.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1215395.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1358045.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0694760.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1736110.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0573369.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2123970.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0716437.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1415430.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1790921.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0198440.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307327.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0205769.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1179713.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0683605.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1188038.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1188390.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1552206.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0512072.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1764197.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0109652.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1540006.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1696014.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1414824.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0076795.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0081597.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1924286.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1133482.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2030599.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1272643.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1043797.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0136179.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1319235.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1182368.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0440127.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1218932.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1886145.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0447765.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2035598.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0710666.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0467386.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2106315.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0996336.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0796444.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1395373.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2213677.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1941127.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239753.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1885840.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1036863.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0893717.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1097975.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0521262.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2040355.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1391897.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2211315.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0065125.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1310734.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0065406.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0454534.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1155928.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0740907.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2128746.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0926105.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1586136.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0133434.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2157874.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0799596.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1857540.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2188604.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1413233.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2030080.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1543498.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1910714.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302093.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0097758.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1559373.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1314987.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0792175.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0056324.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1051497.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1588762.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0625402.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1031503.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0853774.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1898332.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0167091.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0962924.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0883339.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0842400.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1567881.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1622762.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0312438.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2255571.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0851647.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0900486.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1784221.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1539298.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1053510.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1054591.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1771968.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0918627.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1043724.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1169799.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0907429.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1997801.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1966298.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1223344.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0250398.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2174787.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2158858.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0576244.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0102242.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0198445.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0198447.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0257376.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1194001.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1389040.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0812909.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0562558.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0295746.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1548863.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1542797.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1135124.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1935749.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1429850.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1065444.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1043764.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0759286.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1560605.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0783899.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0888512.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312250.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1878594.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1540395.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258662.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2188167.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1758544.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0738257.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307278.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2031890.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0441018.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0864663.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2082475.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1941841.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0977327.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1004662.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1397531.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0731728.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2137126.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1085194.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2076551.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1701061.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0488515.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1902199.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1852173.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1933878.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260949.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1018933.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2124079.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1207125.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2194210.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1476339.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1269007.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0361101.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1763802.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1636521.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1620917.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1115293.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0709331.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0123332.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0478314.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0136152.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0875281.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2048576.jpg
# ...
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2067268.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1600342.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2124486.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2101942.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1086833.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1707735.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1984373.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0979622.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1952462.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2096267.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0174049.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0939518.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0879367.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0727974.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0684605.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1725762.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1349217.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1161492.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0457162.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1208469.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1892614.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1364162.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1969049.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0182735.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1058012.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1358106.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0072480.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0624128.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0727254.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0968748.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1603712.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313340.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1695906.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0704268.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1221649.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1736158.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2066265.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0728390.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1200890.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1097300.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1577705.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0907301.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0851298.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1420545.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1149050.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0195744.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1095184.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1092415.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1237648.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0457171.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1730671.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1034793.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2220612.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251118.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1857215.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2180833.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0905853.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1000107.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2223255.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1700645.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2195679.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1149855.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1815918.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1384649.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1915066.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0068810.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0483246.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0485222.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259625.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0800914.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244766.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1187784.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0593819.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1254668.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1345199.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1281857.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2176403.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1821463.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1047759.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1842173.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1901160.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0202423.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1035348.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0076836.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0247942.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0880593.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1594713.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0184350.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1067522.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0804670.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1100234.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1354666.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0136240.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2227920.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0730106.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0345877.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0730318.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0586973.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2046689.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1620908.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1796985.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0909293.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1878600.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1573348.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0694463.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1337461.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0894406.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0758359.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0767364.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0758789.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0554595.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1204178.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1682647.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1225157.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1193564.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0205781.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1230196.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0771794.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1604058.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0944166.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1997544.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0931601.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0065767.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0136150.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1306689.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1825682.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2057960.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0875344.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1374697.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0158891.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1857543.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1163792.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0337958.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1354835.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2136394.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0796296.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0091405.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0939547.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0523181.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1846144.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1154890.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1359128.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0066977.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0481841.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2080563.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1222203.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0625762.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0838486.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251094.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1814161.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0694490.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2094229.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1927319.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0428239.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2173639.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0922520.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1569778.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2067972.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0738985.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0368357.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1311421.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1101613.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1423710.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1367495.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0681901.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244006.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236389.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0104832.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0102722.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1607382.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/0691271.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1003141.jpg
# /kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251908.jpg

# %%
import pandas as pd
import numpy as np
import os

# ✅ Base path
base_path = "/kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data"

# ✅ Load mapping files
def load_mapping(file_path, label_type):
    mapping = []
    with open(file_path, 'r') as f:
        for line in f:
            parts = line.strip().split(" ", 1)
            if len(parts) == 2:
                mapping.append((parts[0], parts[1]))
    return pd.DataFrame(mapping, columns=["image", label_type])

variant_df = load_mapping(f"{base_path}/images_variant_trainval.txt", "variant")
family_df = load_mapping(f"{base_path}/images_family_trainval.txt", "family")
maker_df = load_mapping(f"{base_path}/images_manufacturer_trainval.txt", "maker")

# ✅ Merge labels on 'image'
df = variant_df.merge(family_df, on="image").merge(maker_df, on="image")

# ✅ Group by variant to get canonical family & maker
hierarchy = df.groupby("variant")[["family", "maker"]].agg(lambda x: x.mode().iloc[0]).reset_index()

# ✅ Create ID maps
variant_to_id = {v: i for i, v in enumerate(hierarchy["variant"].sort_values().unique())}
family_to_id = {f: i for i, f in enumerate(hierarchy["family"].sort_values().unique())}
maker_to_id = {m: i for i, m in enumerate(hierarchy["maker"].sort_values().unique())}

# ✅ Map IDs
hierarchy["variant_id"] = hierarchy["variant"].map(variant_to_id)
hierarchy["family_id"] = hierarchy["family"].map(family_to_id)
hierarchy["maker_id"] = hierarchy["maker"].map(maker_to_id)

# ✅ Optional: Create lookup dicts for later use
variant_to_family = hierarchy.set_index("variant_id")["family_id"].to_dict()
variant_to_maker = hierarchy.set_index("variant_id")["maker_id"].to_dict()

# ✅ Save CSV
output_path = "/kaggle/working/hierarchy_full.csv"
hierarchy.to_csv(output_path, index=False)

# ✅ Confirm
print("✅ hierarchy_full.csv saved with columns:", hierarchy.columns.tolist())
print(f"🔢 Classes: {len(variant_to_id)} variants, {len(family_to_id)} families, {len(maker_to_id)} makers")
# Out:
# ✅ hierarchy_full.csv saved with columns: ['variant', 'family', 'maker', 'variant_id', 'family_id', 'maker_id']
# 🔢 Classes: 100 variants, 70 families, 30 makers

# %%
# ✅ Step 1: Prepare variant to family/maker hierarchy and task splits
import pandas as pd
import os
import random
import json

# Path to original FGVC Aircraft data
base_path = "/kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data"

# Load mapping from original trainval files
def load_mapping(file_path, label_type):
    mapping = []
    with open(file_path, 'r') as f:
        for line in f:
            parts = line.strip().split(" ", 1)
            if len(parts) == 2:
                mapping.append((parts[0], parts[1]))
    return pd.DataFrame(mapping, columns=["image", label_type])

variant_df = load_mapping(f"{base_path}/images_variant_trainval.txt", "variant")
family_df = load_mapping(f"{base_path}/images_family_trainval.txt", "family")
maker_df = load_mapping(f"{base_path}/images_manufacturer_trainval.txt", "maker")

# Merge into a full image-level dataframe
df = variant_df.merge(family_df, on="image").merge(maker_df, on="image")

# Get the variant-level hierarchy (unique mapping assumed)
hierarchy = df.groupby("variant")[["family", "maker"]].agg(lambda x: x.mode()[0]).reset_index()

# Save the full hierarchy
hierarchy_path = "/kaggle/working/hierarchy_full.csv"
hierarchy.to_csv(hierarchy_path, index=False)

# ✅ Step 2: Split variants into 10 tasks randomly
variants = hierarchy["variant"].tolist()
random.seed(42)
random.shuffle(variants)

num_tasks = 20
variants_per_task = len(variants) // num_tasks

# Build task split dictionary with full hierarchy per variant
task_hierarchy = {}
for i in range(num_tasks):
    task_name = f"task_{i+1}"
    task_variants = variants[i*variants_per_task:(i+1)*variants_per_task]
    task_data = []
    for var in task_variants:
        fam = hierarchy[hierarchy["variant"] == var].iloc[0]["family"]
        mak = hierarchy[hierarchy["variant"] == var].iloc[0]["maker"]
        task_data.append({"variant": var, "family": fam, "manufacturer": mak})
    task_hierarchy[task_name] = task_data

# Save task split to JSON
with open("/kaggle/working/task_split.json", "w") as f:
    json.dump(task_hierarchy, f, indent=4)

print("✅ Task split with hierarchy saved to task_split.json")
# Out:
# ✅ Task split with hierarchy saved to task_split.json

# %%
import os
import json
import torch
from PIL import Image
import numpy as np
from skimage.segmentation import slic
from skimage.util import img_as_float
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from tqdm import tqdm

# ✅ Paths
base_path = "/kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data"
img_dir = os.path.join(base_path, "images")
seg_dir = "/kaggle/working/segment_maps"
mapping_file = "/kaggle/working/mapping.txt"
task_split_path = "/kaggle/working/task_split.json"
variant_label_file = os.path.join(base_path, "images_variant_trainval.txt")

# ✅ Create output directory
os.makedirs(seg_dir, exist_ok=True)
mapping = []

# ✅ Step 1: Load task split
with open(task_split_path, "r") as f:
    task_split = json.load(f)

# ✅ Step 2: Get list of allowed variants from all tasks
all_variants = set()
for task_data in task_split.values():
    for entry in task_data:
        all_variants.add(entry["variant"])

# ✅ Step 3: Safe parser for image → variant mapping
def load_variant_mapping(file_path):
    records = []
    with open(file_path, "r") as f:
        for line in f:
            parts = line.strip().split(" ", 1)
            if len(parts) == 2:
                image, variant = parts
                records.append((image, variant))
    return pd.DataFrame(records, columns=["image", "variant"])

variant_df = load_variant_mapping(variant_label_file)
variant_df = variant_df[variant_df["variant"].isin(all_variants)].drop_duplicates().sort_values("image")

# ✅ Step 4: Generate segment maps only for selected images
print(f"🛫 Generating superpixel maps for {len(variant_df)} images in task variant split...")

skipped = 0

for _, row in tqdm(variant_df.iterrows(), total=len(variant_df)):
    image_id = row["image"]
    img_path = os.path.join(img_dir, f"{image_id}.jpg")
    
    if not os.path.exists(img_path):
        skipped += 1
        continue

    try:
        image = Image.open(img_path).convert("RGB")
        resized = image.resize((224, 224))
        image_np = img_as_float(np.array(resized))

        segments = slic(image_np, n_segments=196, compactness=10, start_label=0)
        flat = segments.flatten()
        encoder = LabelEncoder()
        encoded = encoder.fit_transform(flat)
        normalized_segments = encoded.reshape(224, 224)

        seg_tensor = torch.from_numpy(normalized_segments).long()
        seg_save_path = os.path.join(seg_dir, image_id + ".pt")
        torch.save(seg_tensor, seg_save_path)

        mapping.append(f"{image_id} segment_maps/{image_id}.pt")
    except Exception as e:
        print(f"⚠️ Skipping {image_id}: {e}")
        skipped += 1

# ✅ Save mapping file
with open(mapping_file, "w") as f:
    f.writelines([line + "\n" for line in mapping])

# ✅ Summary
print(f"\n✅ Completed generation of superpixel maps.")
print(f"📝 mapping.txt saved at {mapping_file}")
print(f"✔️  Total segment maps created: {len(mapping)}")
print(f"❌ Skipped or failed images: {skipped}")
# Out:
# 🛫 Generating superpixel maps for 6667 images in task variant split...
# 100%|██████████| 6667/6667 [09:32<00:00, 11.64it/s]
# ✅ Completed generation of superpixel maps.
# 📝 mapping.txt saved at /kaggle/working/mapping.txt
# ✔️  Total segment maps created: 6667
# ❌ Skipped or failed images: 0

# %%
# !mkdir -p cast_models

# %%
# %%writefile cast_models/aircraft_dataset.py
import os
import pandas as pd
import torch
from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as T

class AircraftHCASTDataset(Dataset):
    """
    Aircraft HCAST Dataset for Hierarchical Classification.
    Includes an optional flag to include segment maps or not.
    """
    def __init__(self, image_dir, label_file, image_split_file, mapping_file,
                 transform=None, use_segments=True, debug=False):
        self.image_dir = image_dir
        self.debug = debug
        self.use_segments = use_segments

        # ✅ Default image transform
        self.transform = transform or T.Compose([
            T.Resize((224, 224)),
            T.ToTensor(),
            T.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
        ])

        # ✅ Load hierarchy
        self.hierarchy_df = pd.read_csv(label_file)
        self.variant_map = {
            row["variant"].strip().lower(): (row["variant_id"], row["family_id"], row["maker_id"])
            for _, row in self.hierarchy_df.iterrows()
        }
        self.num_variants = self.hierarchy_df["variant_id"].nunique()
        self.num_families = self.hierarchy_df["family_id"].nunique()
        self.num_makers = self.hierarchy_df["maker_id"].nunique()

        # ✅ Segment path mapping
        if self.use_segments:
            with open(mapping_file, "r") as f:
                self.seg_dict = {
                    line.strip().split()[0]: line.strip().split()[1]
                    for line in f if line.strip()
                }

        # ✅ Init sample storage
        self.samples = []
        self.variants = []
        self.families = []
        self.makers = []
        self.variant_names = []

        known_variants = set(self.variant_map.keys())

        with open(image_split_file, "r") as f:
            for line in f:
                if not line.strip():
                    continue
                try:
                    base_name, variant = line.strip().split(" ", 1)
                except ValueError:
                    if self.debug:
                        print(f"⚠️ Malformed line: {line.strip()}")
                    continue

                variant_norm = variant.strip().lower()
                img_name = base_name + ".jpg"

                if variant_norm not in known_variants:
                    if self.debug:
                        print(f"❌ Unknown variant: {variant}")
                    continue

                # ✅ Segment file check only if use_segments is True
                seg_rel_path = None
                if self.use_segments:
                    if base_name not in self.seg_dict:
                        if self.debug:
                            print(f"❌ Missing segment map: {base_name}")
                        continue
                    seg_rel_path = self.seg_dict[base_name]
                    seg_abs_path = os.path.join("/kaggle/working", seg_rel_path)
                    if not os.path.exists(seg_abs_path):
                        if self.debug:
                            print(f"❌ Segment file missing: {seg_abs_path}")
                        continue

                variant_id, family_id, maker_id = self.variant_map[variant_norm]
                self.samples.append((img_name, variant_norm, seg_rel_path))
                self.variants.append(variant_id)
                self.families.append(family_id)
                self.makers.append(maker_id)
                self.variant_names.append(variant.strip())

        if self.debug:
            print(f"✅ Loaded {len(self.samples)} samples")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_name, variant_norm, seg_rel_path = self.samples[idx]
        img_path = os.path.join(self.image_dir, img_name)

        # ✅ Load image
        image = Image.open(img_path).convert("RGB")
        image_tensor = self.transform(image)

        # ✅ Load segment map if enabled
        segment_map = None
        if self.use_segments:
            seg_path = os.path.join("/kaggle/working", seg_rel_path)
            segment_map = torch.load(seg_path)

        # ✅ Hierarchical labels
        variant_id, family_id, maker_id = self.variant_map[variant_norm]

        return {
            "image": image_tensor,
            "segments": segment_map,
            "variant": torch.tensor(variant_id, dtype=torch.long),
            "family": torch.tensor(family_id, dtype=torch.long),
            "maker": torch.tensor(maker_id, dtype=torch.long),
            "image_name": img_name
        }
# Out:
# Writing cast_models/aircraft_dataset.py

# %%
# %%writefile cast_models/cast.py
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from functools import partial

from timm.models.vision_transformer import VisionTransformer, _cfg
from timm.models.registry import register_model
from timm.models.layers import PatchEmbed, trunc_normal_

from cast_models.utils import segment_mean_nd
from cast_models.graph_pool import GraphPooling
from cast_models.modules import Pooling, ConvStem

__all__ = ['cast_small', 'cast_small_deep', 'cast_base', 'cast_base_deep']

class DynamicHead(nn.Module):
    def __init__(self, in_dim, num_classes):
        super().__init__()
        self.in_dim = in_dim
        self.num_classes = num_classes
        self.head = nn.Linear(in_dim, num_classes)

    def expand(self, num_new_classes):
        new_total = self.num_classes + num_new_classes
        device = self.head.weight.device
        new_head = nn.Linear(self.in_dim, new_total).to(device)
        with torch.no_grad():
            if self.num_classes > 0:
                new_head.weight[:self.num_classes] = self.head.weight
                new_head.bias[:self.num_classes] = self.head.bias
        self.head = new_head
        self.num_classes = new_total

    def forward(self, x):
        return self.head(x)

class CAST(VisionTransformer):
    def __init__(self, *args, **kwargs):
        nb_classes = kwargs.pop('nb_classes', None)
        init_num_classes = kwargs.pop('init_num_classes', 5)
        dropout_rate = kwargs.pop('dropout_rate', 0.1)
        assert nb_classes is not None, "You must provide nb_classes"

        depths = kwargs['depth']
        num_clusters = kwargs.pop('num_clusters', [64, 32, 16, 8])
        kwargs['depth'] = sum(depths)
        kwargs['drop_rate'] = dropout_rate
        kwargs['attn_drop_rate'] = dropout_rate
        kwargs['drop_path_rate'] = dropout_rate

        super().__init__(*args, **kwargs)

        if hasattr(self, 'dist_token'):
            del self.dist_token
        if hasattr(self, 'head_dist'):
            del self.head_dist

        if len(nb_classes) == 3:
            self.total_classes, self.num_family, self.num_manufacturer = nb_classes
        elif len(nb_classes) == 2:
            self.total_classes, self.num_family = nb_classes
            self.num_manufacturer = 0
        else:
            self.total_classes = nb_classes[0]
            self.num_family = 0
            self.num_manufacturer = 0

        # Start all heads at 0 for dynamic expansion
        self.head = DynamicHead(self.embed_dim, init_num_classes)
        self.family_head = DynamicHead(self.embed_dim, 0)
        self.manufacturer_head = DynamicHead(self.embed_dim, 0)

        patch_H, patch_W = self.patch_embed.grid_size
        num_patches = patch_H * patch_W
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, self.embed_dim))
        trunc_normal_(self.pos_embed, std=.02)

        cumsum = [0]
        for d in depths:
            cumsum.append(cumsum[-1] + d)
        assert sum(depths) == len(self.blocks)

        blocks, pools = [], []
        for i, d in enumerate(depths):
            blocks.append(self.blocks[cumsum[i]:cumsum[i + 1]])
            pool = Pooling(pool_block=GraphPooling(
                num_clusters=num_clusters[i],
                d_model=self.embed_dim,
                l2_normalize_for_fps=False
            ))
            if i == len(depths) - 1:
                for m in (pool.pool_block.fc1, pool.pool_block.fc2, pool.pool_block.centroid_fc):
                    for p in m.parameters():
                        p.requires_grad = False
            pools.append(pool)

        self.blocks1, self.pool1 = blocks[0], pools[0]
        self.blocks2, self.pool2 = blocks[1], pools[1]
        self.blocks3, self.pool3 = blocks[2], pools[2]
        self.blocks4, self.pool4 = blocks[3], pools[3]

    def _block_operations(self, x, cls_token, pad_mask, nn_block, pool_block, norm_block):
        cls_x = torch.cat([cls_token, x], dim=1)
        cls_x = nn_block(cls_x).type_as(x)
        cls_token, x = cls_x[:, :1], cls_x[:, 1:]

        cls_token, logit, centroid, new_mask, inds = pool_block(cls_token, x, pad_mask)
        out = norm_block(cls_x)[:, 0] if norm_block else cls_x[:, 0]
        return x, cls_token, logit, centroid, new_mask, inds, out

    def forward_features(self, x, y):
        x = self.patch_embed(x)
        N, H, W, C = x.shape
        y = F.interpolate(y.unsqueeze(1).float(), (H, W), mode='nearest').squeeze(1).long()
        ones = torch.ones((N, H, W, 1), device=x.device)
        avg = segment_mean_nd(ones, y).squeeze(-1)
        pad = avg <= 0.5
        x = segment_mean_nd(x, y)
        pos = segment_mean_nd(
            self.pos_embed[:, 1:].view(1, H, W, C).expand(N, -1, -1, -1), y
        )
        x = self.pos_drop(x + pos)
        cls = self.cls_token.expand(N, -1, -1) + self.pos_embed[:, :1]

        x, cls1, _, cent1, pad1, _, _ = self._block_operations(x, cls, pad, self.blocks1, self.pool1, None)
        x, cls2, _, cent2, pad2, _, out2 = self._block_operations(cent1, cls1, pad1, self.blocks2, self.pool2, None)
        x, cls3, _, cent3, pad3, _, out3 = self._block_operations(cent2, cls2, pad2, self.blocks3, self.pool3, None)
        _, _, _, _, _, _, out4 = self._block_operations(cent3, cls3, pad3, self.blocks4, self.pool4, self.norm)

        return out2, out3, out4

    def forward(self, x, y):
        out2, out3, out4 = self.forward_features(x, y)
        logits = self.head(out2)
        fam_logits = self.family_head(out3)
        man_logits = self.manufacturer_head(out4)
        return logits, fam_logits, man_logits

@register_model
def cast_small(pretrained=False, **kwargs):
    model = CAST(
        patch_size=8, embed_dim=384, num_clusters=[64, 32, 16, 8],
        depth=[3, 3, 3, 2], num_heads=12, mlp_ratio=4, qkv_bias=True,
        norm_layer=partial(nn.LayerNorm, eps=1e-6), embed_layer=ConvStem,
        **kwargs)
    model.default_cfg = _cfg()
    return model

@register_model
def cast_small_deep(pretrained=False, **kwargs):
    model = CAST(
        patch_size=8, embed_dim=384, num_clusters=[64, 32, 16, 8],
        depth=[6, 3, 3, 3], num_heads=12, mlp_ratio=4, qkv_bias=True,
        norm_layer=partial(nn.LayerNorm, eps=1e-6), embed_layer=ConvStem,
        **kwargs)
    model.default_cfg = _cfg()
    return model

@register_model
def cast_base(pretrained=False, **kwargs):
    model = CAST(
        patch_size=8, embed_dim=768, num_clusters=[64, 32, 16, 8],
        depth=[3, 3, 3, 2], num_heads=12, mlp_ratio=4, qkv_bias=True,
        norm_layer=partial(nn.LayerNorm, eps=1e-6), embed_layer=ConvStem,
        **kwargs)
    model.default_cfg = _cfg()
    return model

@register_model
def cast_base_deep(pretrained=False, **kwargs):
    model = CAST(
        patch_size=8, embed_dim=768, num_clusters=[64, 32, 16, 8],
        depth=[6, 3, 3, 3], num_heads=12, mlp_ratio=4, qkv_bias=True,
        norm_layer=partial(nn.LayerNorm, eps=1e-6), embed_layer=ConvStem,
        **kwargs)
    model.default_cfg = _cfg()
    return model
# Out:
# Writing cast_models/cast.py

# %%
# %%writefile cast_models/graph_pool.py

import math
from functools import partial

import torch
import torch.nn as nn
import torch.nn.functional as F

from cast_models.utils import farthest_point_sampling
from cast_models.utils import segment_mean_nd


class Attention(nn.Module):
    def __init__(self, dim, num_heads=8, qkv_bias=False, attn_drop=0., proj_drop=0.):
        super().__init__()
        assert dim % num_heads == 0, 'dim must be divisible by num_heads'
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x).reshape(B, N, 3, self.num_heads, C // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv.unbind(0)

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class Block(nn.Module):
    def __init__(self, dim, num_heads, qkv_bias=False, drop=0., attn_drop=0., norm_layer=nn.LayerNorm):
        super().__init__()
        self.norm = norm_layer(dim)
        self.attn = Attention(dim, num_heads, qkv_bias, attn_drop, drop)
        self.drop_path = nn.Identity()
        self.bias = nn.Parameter(torch.zeros(dim).normal_(0, 1e-2))

    def forward(self, x):
        x = x + self.drop_path(self.attn(self.norm(x)))
        x = x - x.mean(dim=1, keepdim=True) + self.bias.view(1, 1, -1)
        return x


class GraphPooling(nn.Module):
    def __init__(
        self,
        num_clusters=4,
        d_model=512,
        dropout=0.1,
        l2_normalize_for_fps=True,
        num_heads=12,
        qkv_bias=True,
        norm_layer=partial(nn.LayerNorm, eps=1e-6)
    ):
        super().__init__()
        self._num_clusters = num_clusters
        self._l2_normalize_for_fps = l2_normalize_for_fps

        self.centroid_fc = Block(d_model, num_heads, qkv_bias, norm_layer=norm_layer)
        self.fc1 = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_model * 4),
            nn.GELU(),
            nn.Dropout(dropout)
        )
        self.fc2 = nn.Sequential(
            nn.LayerNorm(d_model * 4),
            nn.Linear(d_model * 4, d_model)
        )

    def _fill_with_mean(self, src, mask):
        bs, sl, cs = src.shape
        if mask is not None:
            mean_src = valid_mean(src, ~mask).unsqueeze(1).type_as(src)
            fill_mask = mask.unsqueeze(2).expand(-1, -1, cs)
            filled_src = torch.where(fill_mask, mean_src.expand(-1, sl, -1), src)
        else:
            mean_src = src.mean(dim=1, keepdim=True)
            filled_src = src
        return filled_src, mean_src

    def forward(self, cls_token, src, mask=None):
        bs, sl, cs = src.shape

        if sl < self._num_clusters:
            raise ValueError(f"Too few tokens ({sl}) to sample {self._num_clusters} clusters.")

        filled_src, mean_src = self._fill_with_mean(src, mask)
        padded_src = torch.cat([mean_src, filled_src], dim=1)

        sampling_src = F.normalize(padded_src, dim=-1) if self._l2_normalize_for_fps else padded_src
        sampled_inds = farthest_point_sampling(sampling_src, self._num_clusters).clamp(0, sl - 1)
        unfold_inds = sampled_inds.unsqueeze(2).expand(-1, -1, cs)

        node_features = self.centroid_fc(src)
        centroid_feats = torch.gather(node_features, 1, unfold_inds)

        norm_node = F.normalize(node_features, dim=-1)
        norm_centroid = F.normalize(centroid_feats, dim=-1)
        logits = torch.matmul(norm_node, norm_centroid.transpose(1, 2)) * 5
        assignments = torch.softmax(logits, dim=-1)

        fc1_cls_src = self.fc1(torch.cat([cls_token, src], dim=1))
        fc1_cls, fc1_src = fc1_cls_src[:, :1], fc1_cls_src[:, 1:]

        normalizer = assignments.transpose(1, 2) @ torch.ones((bs, sl, 1), dtype=src.dtype, device=src.device)
        centroid = assignments.transpose(1, 2) @ fc1_src
        centroid = centroid / (normalizer + 1e-6)

        fc2_out = self.fc2(torch.cat([fc1_cls, centroid], dim=1))
        new_cls = fc2_out[:, :1, :] + cls_token
        new_centroid = fc2_out[:, 1:, :] + torch.gather(src, 1, unfold_inds)

        out = new_cls.squeeze(1)  # Final graph representation
        new_mask = None  # Placeholder for hierarchy-aware masking

        return new_cls, logits, new_centroid, new_mask, sampled_inds, out


def valid_mean(x, mask):
    mask = mask.type_as(x).unsqueeze(2)  # [B, N, 1]
    sum_mask = torch.clamp(mask.sum(dim=1), min=1)
    masked_x = x * mask
    mean_x = masked_x.sum(dim=1) / sum_mask
    return mean_x
# Out:
# Writing cast_models/graph_pool.py

# %%
# %%writefile cast_models/modules.py
"""Define shared modules"""
import torch
import torch.nn as nn

from timm.layers.helpers import to_2tuple


class Pooling(nn.Module):

    def __init__(self, pool_block):
        super(Pooling, self).__init__()
        self.pool_block = pool_block

    def forward(self, cls_token, x, padding_mask=None):
        cls_token, pool_logit, centroid, new_mask, sampled_x_inds, out = self.pool_block(cls_token=cls_token, src=x, mask=padding_mask)

        pool_padding_mask = torch.zeros(
            (pool_logit.shape[0], pool_logit.shape[-1]),
            dtype=torch.bool,
            device=pool_logit.device)

        return cls_token, pool_logit, centroid, pool_padding_mask, sampled_x_inds


class ConvStem(nn.Module):
    def __init__(self, img_size=224, patch_size=8, in_chans=3, embed_dim=768, norm_layer=None, flatten=False, **kwargs):
        super().__init__()
        assert patch_size == 8, 'ConvStem only supports patch size of 8'
        assert embed_dim % 8 == 0, 'Embed dimension must be divisible by 2 for ConvStem'

        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        self.img_size = img_size
        self.patch_size = patch_size
        self.grid_size = (img_size[0] // patch_size[0], img_size[1] // patch_size[1])
        self.num_patches = self.grid_size[0] * self.grid_size[1]
        self.flatten = flatten

        stem = []
        input_dim, output_dim = in_chans, embed_dim // 8
        for l in range(4):
            stride = 2 if l < 3 else 1
            stem.append(nn.Conv2d(input_dim, output_dim, kernel_size=3, stride=stride, padding=1, bias=False))
            stem.append(nn.BatchNorm2d(output_dim))
            stem.append(nn.ReLU(inplace=True))
            input_dim = output_dim
            output_dim *= 2
        stem.append(nn.Conv2d(input_dim, embed_dim, kernel_size=1))
        self.proj = nn.Sequential(*stem)

        self.norm = norm_layer(embed_dim) if norm_layer else nn.Identity()

    def forward(self, x):
        x = self.proj(x)
        if self.flatten:
            x = x.flatten(2).transpose(1, 2)
        else:
            x = x.permute(0, 2, 3, 1)
        x = self.norm(x)
        return x


class _BatchNorm1d(nn.Module):
    def __init__(self, num_features, eps=1e-5, momentum=0.1, affine=True, track_running_stats=True):
        super(_BatchNorm1d, self).__init__()
        self.norm = nn.BatchNorm1d(num_features=num_features,
                                   eps=eps,
                                   momentum=momentum,
                                   affine=affine,
                                   track_running_stats=track_running_stats)

    def forward(self, x):
        return self.norm(x.transpose(1, 2)).transpose(1, 2)


class BlockFusion(nn.Module):
    def __init__(self, dim, block4_identity=True, discrete=True):
        super(BlockFusion, self).__init__()
        self.proj_blocks = self._make_proj_block(dim * 4, dim)
        self._discrete = discrete

    def _make_proj_block(self, in_dim, out_dim):
        return nn.Sequential(
            _BatchNorm1d(in_dim),
            nn.Dropout(0.2),
            nn.Linear(in_dim, out_dim, bias=True)
        )

    def _unpool(self, block, label):
        bs, ns, cs = block.shape
        label = label.unsqueeze(2).expand(-1, -1, cs)
        return torch.gather(block, 1, label)

    def _proj_block_operations(self, x, cls_token, proj_block):
        cls_x = torch.cat([cls_token, x], dim=1)
        cls_x = proj_block(cls_x).type_as(x)
        return cls_x[:, 1:, :], cls_x[:, :1, :]

    def forward(self, block1, block2, block3, block4,
                cls_token1, cls_token2, cls_token3, cls_token4,
                logit1_2, logit2_3, logit3_4):

        if not self._discrete:
            raise NotImplementedError("Only support discrete unpooling")

        label1_2 = torch.argmax(logit1_2, dim=-1)
        label2_3 = torch.argmax(logit2_3, dim=-1)
        label3_4 = torch.argmax(logit3_4, dim=-1)

        label1_3 = torch.gather(label2_3, 1, label1_2)
        label1_4 = torch.gather(label3_4, 1, label1_3)

        block2 = self._unpool(block2, label1_2)
        block3 = self._unpool(block3, label1_3)
        block4 = self._unpool(block4, label1_4)

        out_block = torch.cat([block1, block2, block3, block4], dim=-1)
        out_cls_token = torch.cat([cls_token1, cls_token2, cls_token3, cls_token4], dim=-1)

        out_block, out_cls_token = self._proj_block_operations(
            out_block, out_cls_token, self.proj_blocks)

        return out_block, out_cls_token
# Out:
# Writing cast_models/modules.py

# %%
# %%writefile cast_models/engine_hier.py
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import defaultdict

def train_one_epoch(model, criterion, data_loader, optimizer, device, epoch,
                    loss_scaler=None, model_ema=None, mixup_fn=None,
                    set_training_mode=True, args=None,
                    task_classes=None,
                    variant_to_family_matrix=None,
                    variant_to_maker_matrix=None,
                    ewc_loss_fn=None):  # ✅ NEW ARG
    model.train(set_training_mode)
    metric_logger = defaultdict(float)
    metric_logger["ewc_loss"] = 0.0  # ✅ Initialize EWC loss tracking
    total_batches = len(data_loader)

    for batch_idx, batch in enumerate(data_loader):
        images = batch["image"].to(device)
        segments = batch["segments"].to(device)
        targets = batch["variant"].to(device)
        family_targets = batch["family"].to(device)
        manu_targets = batch["maker"].to(device)

        if mixup_fn is not None:
            images, targets, family_targets, manu_targets = mixup_fn(
                images, (targets, family_targets, manu_targets)
            )

        logits, family_logits, manu_logits = model(images, segments)

        loss_s = criterion(images, logits, targets)
        loss_f = criterion(images, family_logits, family_targets)
        loss_m = criterion(images, manu_logits, manu_targets)

        total_loss = loss_s + loss_f + loss_m

        # ✅ Global KL loss
        if args.globalkl and variant_to_family_matrix is not None and targets.ndim == 1:
            # Compute softmax probabilities from variant logits (no gradient)
            variant_probs = F.softmax(logits.detach(), dim=-1)
        
            # Derive soft targets using class hierarchy
            family_targets_soft = variant_probs @ variant_to_family_matrix
            manu_targets_soft = variant_probs @ variant_to_maker_matrix
        
            # Ensure numerical stability
            family_targets_soft = family_targets_soft.clamp(min=1e-8)
            manu_targets_soft = manu_targets_soft.clamp(min=1e-8)
        
            # Compute KL divergence between predicted logits and hierarchy-induced targets
            family_kl = F.kl_div(
                F.log_softmax(family_logits, dim=-1),
                family_targets_soft,
                reduction='batchmean'
            )
            manu_kl = F.kl_div(
                F.log_softmax(manu_logits, dim=-1),
                manu_targets_soft,
                reduction='batchmean'
            )
        
            # Add to total loss
            global_kl_loss = args.gk_weight * (family_kl + manu_kl)
            total_loss += global_kl_loss
            metric_logger["globalkl_loss"] += global_kl_loss.item()

            # Optional: Debug prints
            if hasattr(args, 'debug') and args.debug:
                print(f"[Epoch {epoch} | Batch {batch_idx}]")
                print(f"  V2F matrix sum: {variant_to_family_matrix.sum().item():.4f}")
                print(f"  V2M matrix sum: {variant_to_maker_matrix.sum().item():.4f}")
                print(f"  family_kl: {family_kl.item():.6f}, manu_kl: {manu_kl.item():.6f}")
                print(f"  global_kl_loss: {global_kl_loss.item():.6f}")

        # ✅ Add EWC loss if available
        if ewc_loss_fn is not None and len(ewc_loss_fn.tasks_encountered) > 0:
            ewc_loss = ewc_loss_fn.regularize(model.named_parameters())
            total_loss += ewc_loss
            metric_logger["ewc_loss"] += ewc_loss.item()
        
            if hasattr(args, 'debug') and args.debug:
                print(f"  ewc_loss: {ewc_loss.item():.6f}")

        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

        # Logging metrics
        with torch.no_grad():
            acc1 = accuracy(logits, batch["variant"].to(device), topk=(1,))[0]
            acc5 = accuracy(logits, batch["variant"].to(device), topk=(5,))[0]
            fam_acc1 = accuracy(family_logits, batch["family"].to(device), topk=(1,))[0]
            manu_acc1 = accuracy(manu_logits, batch["maker"].to(device), topk=(1,))[0]

        metric_logger["sploss"] += loss_s.item()
        metric_logger["fmloss"] += loss_f.item()
        metric_logger["mfloss"] += loss_m.item()
        metric_logger["acc1"] += acc1.item()
        metric_logger["acc5"] += acc5.item()
        metric_logger["family_acc1"] += fam_acc1.item()
        metric_logger["manu_acc1"] += manu_acc1.item()

    # Average metrics
    for k in metric_logger:
        metric_logger[k] /= total_batches

    return metric_logger

def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res
# Out:
# Writing cast_models/engine_hier.py

# %%
# %%writefile cast_models/utils.py

"""Utilility function for all.
"""
# This code is borrowed and re-implemented from:
# https://github.com/jyhjinghwang/SegSort/blob/master/network/segsort/vis_utils.py
# https://github.com/jyhjinghwang/SegSort/blob/master/network/segsort/common_utils.py

import torch
import torch.nn.functional as F
import time
import datetime
from collections import defaultdict, deque

def resize_labels(labels, size):
    n, h, w = labels.shape
    labels = F.interpolate(labels.view(n, 1, h, w).float(), size=size, mode='nearest')
    labels = labels.squeeze_(1).long()
    return labels

def calculate_principal_components(embeddings, num_components=3):
    embeddings = embeddings - torch.mean(embeddings, 0, keepdim=True)
    _, _, v = torch.svd(embeddings)
    return v[:, :num_components]

def pca(embeddings, num_components=3, principal_components=None):
    shape = embeddings.shape
    embeddings = embeddings.view(-1, shape[-1])
    if principal_components is None:
        principal_components = calculate_principal_components(embeddings, num_components)
    embeddings = torch.mm(embeddings, principal_components)
    new_shape = list(shape[:-1]) + [num_components]
    embeddings = embeddings.view(new_shape)
    return embeddings

def one_hot(labels, max_label=None):
    if max_label is None:
        max_label = labels.max() + 1
    shape = labels.shape
    labels = labels.view(-1, 1)
    one_hot_labels = torch.zeros((labels.shape[0], max_label), dtype=torch.long, device=labels.device)
    one_hot_labels = one_hot_labels.scatter_(1, labels, 1)
    new_shape = list(shape) + [max_label]
    one_hot_labels = one_hot_labels.view(new_shape)
    return one_hot_labels

def normalize_embedding(embeddings, eps=1e-12):
    norm = torch.norm(embeddings, dim=-1, keepdim=True)
    norm = torch.where(torch.ge(norm, eps), norm, torch.ones_like(norm).mul_(eps))
    return embeddings / norm

def segment_mean(x, index):
    x = x.reshape(-1, x.shape[-1])
    index = index.reshape(-1)
    if torch.any(index < 0):
        raise ValueError("segment_mean error: `index` contains negative values.")
    max_index = index.max().item() + 1
    sum_x = torch.zeros((max_index, x.shape[-1]), dtype=x.dtype, device=x.device)
    count = torch.zeros((max_index,), dtype=x.dtype, device=x.device)
    count = count.scatter_add(0, index, torch.ones_like(index, dtype=x.dtype))
    index_2d = index.unsqueeze(1).expand(-1, x.shape[-1])
    sum_x = sum_x.scatter_add(0, index_2d, x)
    count = torch.clamp(count, min=1.0)
    mean_x = sum_x / count.unsqueeze(1)
    return mean_x

def segment_mean_nd(x, index, start_dim=-3, end_dim=-2):
    if start_dim < 0:
        start_dim = x.dim() + start_dim
    if end_dim < 0:
        end_dim = x.dim() + end_dim
    batch_dims = list(x.shape[:start_dim])
    C = x.shape[-1]
    x = x.reshape(-1, C)
    index = index.reshape(-1)
    if torch.any(index < 0):
        raise ValueError("segment_mean_nd error: `index` contains negative values.")
    B = batch_dims[0]
    max_seg_id = index.max().item() + 1
    batch_ids = torch.arange(B, device=index.device).repeat_interleave(index.numel() // B)
    global_index = batch_ids * max_seg_id + index
    mean_x = segment_mean(x, global_index)
    expected_len = B * max_seg_id
    if mean_x.shape[0] < expected_len:
        mean_x = F.pad(mean_x, (0, 0, 0, expected_len - mean_x.shape[0]))
    mean_x = mean_x.reshape(B, max_seg_id, C)
    return mean_x

def farthest_point_sampling(x, k):
    B, N, C = x.shape
    indices = torch.zeros((B, k), dtype=torch.long, device=x.device)
    farthest = torch.randint(0, N, (B,), dtype=torch.long, device=x.device)
    distances = torch.full((B, N), float('inf'), device=x.device)
    for i in range(k):
        indices[:, i] = farthest
        centroid = x[torch.arange(B), farthest].unsqueeze(1)
        dist = ((x - centroid) ** 2).sum(-1)
        mask = dist < distances
        distances[mask] = dist[mask]
        farthest = distances.max(-1)[1]
    return indices

class NativeScalerWithGradNormCount:
    def __init__(self):
        self.scaler = torch.cuda.amp.GradScaler()

    def __call__(self, loss, optimizer, clip_grad=None, parameters=None, create_graph=False):
        self.scaler.scale(loss).backward(create_graph=create_graph)
        if clip_grad is not None:
            self.scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(parameters, clip_grad)
        self.scaler.step(optimizer)
        self.scaler.update()
        optimizer.zero_grad()

class SmoothedValue:
    def __init__(self, window_size=20, fmt=None):
        self.deque = deque(maxlen=window_size)
        self.total = 0.0
        self.count = 0
        self.fmt = fmt if fmt else "{median:.4f} ({global_avg:.4f})"

    def update(self, value, n=1):
        self.deque.append(value)
        self.count += n
        self.total += value * n

    @property
    def median(self):
        d = torch.tensor(list(self.deque))
        return d.median().item()

    @property
    def avg(self):
        d = torch.tensor(list(self.deque), dtype=torch.float32)
        return d.mean().item()

    @property
    def global_avg(self):
        return self.total / self.count if self.count > 0 else 0

    def __str__(self):
        return self.fmt.format(median=self.median, global_avg=self.global_avg)

class MetricLogger:
    def __init__(self, delimiter="\t"):
        self.meters = defaultdict(SmoothedValue)
        self.delimiter = delimiter

    def update(self, **kwargs):
        for k, v in kwargs.items():
            if isinstance(v, torch.Tensor):
                v = v.item()
            self.meters[k].update(v)

    def __str__(self):
        return self.delimiter.join(f"{name}: {meter}" for name, meter in self.meters.items())

    def add_meter(self, name, meter):
        self.meters[name] = meter

    def log_every(self, iterable, print_freq, header=None):
        i = 0
        start_time = time.time()
        for obj in iterable:
            yield obj
            if i % print_freq == 0:
                elapsed = time.time() - start_time
                print_str = [header or "", f"[{i}/{len(iterable)}]"]
                print_str += [f"{name}: {str(meter)}" for name, meter in self.meters.items()]
                print_str.append(f"time: {elapsed:.2f}s")
                print(self.delimiter.join(print_str))
            i += 1
# Out:
# Writing cast_models/utils.py

# %%
# %%writefile cast_models/mixup_hier.py

import numpy as np
import torch


def one_hot(x, num_classes, on_value=1., off_value=0.):
    x = x.long().view(-1, 1)

    # ✅ Add debug check before scatter
    if torch.any(x < 0) or torch.any(x >= num_classes):
        print(f"🔥 ERROR: Found out-of-bound label in one_hot! Min: {x.min().item()}, Max: {x.max().item()}, Num classes: {num_classes}")
        raise ValueError("Labels out of range for one_hot encoding.")

    return torch.full((x.size()[0], num_classes), off_value, device=x.device).scatter_(1, x, on_value)



def mixup_target(target, num_classes, lam=1., smoothing=0.0):
    off_value = smoothing / num_classes
    on_value = 1. - smoothing + off_value
    y1 = one_hot(target, num_classes, on_value=on_value, off_value=off_value)
    y2 = one_hot(target.flip(0), num_classes, on_value=on_value, off_value=off_value)
    return y1 * lam + y2 * (1. - lam)


def rand_bbox(img_shape, lam, margin=0., count=None):
   
    ratio = np.sqrt(1 - lam)
    img_h, img_w = img_shape[-2:]
    cut_h, cut_w = int(img_h * ratio), int(img_w * ratio)
    margin_y, margin_x = int(margin * cut_h), int(margin * cut_w)
    cy = np.random.randint(0 + margin_y, img_h - margin_y, size=count)
    cx = np.random.randint(0 + margin_x, img_w - margin_x, size=count)
    yl = np.clip(cy - cut_h // 2, 0, img_h)
    yh = np.clip(cy + cut_h // 2, 0, img_h)
    xl = np.clip(cx - cut_w // 2, 0, img_w)
    xh = np.clip(cx + cut_w // 2, 0, img_w)
    return yl, yh, xl, xh


def rand_bbox_minmax(img_shape, minmax, count=None):
   
    assert len(minmax) == 2
    img_h, img_w = img_shape[-2:]
    cut_h = np.random.randint(int(img_h * minmax[0]), int(img_h * minmax[1]), size=count)
    cut_w = np.random.randint(int(img_w * minmax[0]), int(img_w * minmax[1]), size=count)
    yl = np.random.randint(0, img_h - cut_h, size=count)
    xl = np.random.randint(0, img_w - cut_w, size=count)
    yu = yl + cut_h
    xu = xl + cut_w
    return yl, yu, xl, xu


def cutmix_bbox_and_lam(img_shape, lam, ratio_minmax=None, correct_lam=True, count=None):
    """ Generate bbox and apply lambda correction.
    """
    if ratio_minmax is not None:
        yl, yu, xl, xu = rand_bbox_minmax(img_shape, ratio_minmax, count=count)
    else:
        yl, yu, xl, xu = rand_bbox(img_shape, lam, count=count)
    if correct_lam or ratio_minmax is not None:
        bbox_area = (yu - yl) * (xu - xl)
        lam = 1. - bbox_area / float(img_shape[-2] * img_shape[-1])
    return (yl, yu, xl, xu), lam


class Mixup:
  
    def __init__(self, mixup_alpha=1., cutmix_alpha=0., cutmix_minmax=None, prob=1.0, switch_prob=0.5,
                 mode='batch', correct_lam=True, label_smoothing=0.1, num_classes=[100, 70, 30]):
        self.mixup_alpha = mixup_alpha
        self.cutmix_alpha = cutmix_alpha
        self.cutmix_minmax = cutmix_minmax
        if self.cutmix_minmax is not None:
            assert len(self.cutmix_minmax) == 2
            # force cutmix alpha == 1.0 when minmax active to keep logic simple & safe
            self.cutmix_alpha = 1.0
        self.mix_prob = prob
        self.switch_prob = switch_prob
        self.label_smoothing = label_smoothing
        self.num_classes = num_classes
        self.mode = mode
        self.correct_lam = correct_lam  # correct lambda based on clipped area for cutmix
        self.mixup_enabled = True  # set to false to disable mixing (intended tp be set by train loop)

    def _params_per_elem(self, batch_size):
        lam = np.ones(batch_size, dtype=np.float32)
        use_cutmix = np.zeros(batch_size, dtype=bool)
        if self.mixup_enabled:
            if self.mixup_alpha > 0. and self.cutmix_alpha > 0.:
                use_cutmix = np.random.rand(batch_size) < self.switch_prob
                lam_mix = np.where(
                    use_cutmix,
                    np.random.beta(self.cutmix_alpha, self.cutmix_alpha, size=batch_size),
                    np.random.beta(self.mixup_alpha, self.mixup_alpha, size=batch_size))
            elif self.mixup_alpha > 0.:
                lam_mix = np.random.beta(self.mixup_alpha, self.mixup_alpha, size=batch_size)
            elif self.cutmix_alpha > 0.:
                use_cutmix = np.ones(batch_size, dtype=bool)
                lam_mix = np.random.beta(self.cutmix_alpha, self.cutmix_alpha, size=batch_size)
            else:
                assert False, "One of mixup_alpha > 0., cutmix_alpha > 0., cutmix_minmax not None should be true."
            lam = np.where(np.random.rand(batch_size) < self.mix_prob, lam_mix.astype(np.float32), lam)
        return lam, use_cutmix

    def _params_per_batch(self):
        lam = 1.
        use_cutmix = False
        if self.mixup_enabled and np.random.rand() < self.mix_prob:
            if self.mixup_alpha > 0. and self.cutmix_alpha > 0.:
                use_cutmix = np.random.rand() < self.switch_prob
                lam_mix = np.random.beta(self.cutmix_alpha, self.cutmix_alpha) if use_cutmix else \
                    np.random.beta(self.mixup_alpha, self.mixup_alpha)
            elif self.mixup_alpha > 0.:
                lam_mix = np.random.beta(self.mixup_alpha, self.mixup_alpha)
            elif self.cutmix_alpha > 0.:
                use_cutmix = True
                lam_mix = np.random.beta(self.cutmix_alpha, self.cutmix_alpha)
            else:
                assert False, "One of mixup_alpha > 0., cutmix_alpha > 0., cutmix_minmax not None should be true."
            lam = float(lam_mix)
        return lam, use_cutmix

    def _mix_elem(self, x):
        batch_size = len(x)
        lam_batch, use_cutmix = self._params_per_elem(batch_size)
        x_orig = x.clone()  # need to keep an unmodified original for mixing source
        for i in range(batch_size):
            j = batch_size - i - 1
            lam = lam_batch[i]
            if lam != 1.:
                if use_cutmix[i]:
                    (yl, yh, xl, xh), lam = cutmix_bbox_and_lam(
                        x[i].shape, lam, ratio_minmax=self.cutmix_minmax, correct_lam=self.correct_lam)
                    x[i][:, yl:yh, xl:xh] = x_orig[j][:, yl:yh, xl:xh]
                    lam_batch[i] = lam
                else:
                    x[i] = x[i] * lam + x_orig[j] * (1 - lam)
        return torch.tensor(lam_batch, device=x.device, dtype=x.dtype).unsqueeze(1)

    def _mix_pair(self, x):
        batch_size = len(x)
        lam_batch, use_cutmix = self._params_per_elem(batch_size // 2)
        x_orig = x.clone()  # need to keep an unmodified original for mixing source
        for i in range(batch_size // 2):
            j = batch_size - i - 1
            lam = lam_batch[i]
            if lam != 1.:
                if use_cutmix[i]:
                    (yl, yh, xl, xh), lam = cutmix_bbox_and_lam(
                        x[i].shape, lam, ratio_minmax=self.cutmix_minmax, correct_lam=self.correct_lam)
                    x[i][:, yl:yh, xl:xh] = x_orig[j][:, yl:yh, xl:xh]
                    x[j][:, yl:yh, xl:xh] = x_orig[i][:, yl:yh, xl:xh]
                    lam_batch[i] = lam
                else:
                    x[i] = x[i] * lam + x_orig[j] * (1 - lam)
                    x[j] = x[j] * lam + x_orig[i] * (1 - lam)
        lam_batch = np.concatenate((lam_batch, lam_batch[::-1]))
        return torch.tensor(lam_batch, device=x.device, dtype=x.dtype).unsqueeze(1)

    def _mix_batch(self, x):
        lam, use_cutmix = self._params_per_batch()
        if lam == 1.:
            return 1.
        if use_cutmix:
            (yl, yh, xl, xh), lam = cutmix_bbox_and_lam(
                x.shape, lam, ratio_minmax=self.cutmix_minmax, correct_lam=self.correct_lam)
            x[:, :, yl:yh, xl:xh] = x.flip(0)[:, :, yl:yh, xl:xh]
        else:
            x_flipped = x.flip(0).mul_(1. - lam)
            x.mul_(lam).add_(x_flipped)
        return lam

    def __call__(self, x, target):
        assert len(x) % 2 == 0, 'Batch size should be even when using this'
        if self.mode == 'elem':
            lam = self._mix_elem(x)
        elif self.mode == 'pair':
            lam = self._mix_pair(x)
        else:
            lam = self._mix_batch(x)
        species_target = mixup_target(target[0], self.num_classes[0], lam, self.label_smoothing)
        family_target = mixup_target(target[1], self.num_classes[1], lam, self.label_smoothing)
        if len(self.num_classes) == 2:
            return x, species_target, family_target
        elif len(self.num_classes) == 3:
            manu_target = mixup_target(target[2], self.num_classes[2], lam, self.label_smoothing)
            return x, species_target, family_target, manu_target


class FastCollateMixup(Mixup):
    """ Fast Collate w/ Mixup/Cutmix that applies different params to each element or whole batch

    A Mixup impl that's performed while collating the batches.
    """

    def _mix_elem_collate(self, output, batch, half=False):
        batch_size = len(batch)
        num_elem = batch_size // 2 if half else batch_size
        assert len(output) == num_elem
        lam_batch, use_cutmix = self._params_per_elem(num_elem)
        for i in range(num_elem):
            j = batch_size - i - 1
            lam = lam_batch[i]
            mixed = batch[i][0]
            if lam != 1.:
                if use_cutmix[i]:
                    if not half:
                        mixed = mixed.copy()
                    (yl, yh, xl, xh), lam = cutmix_bbox_and_lam(
                        output.shape, lam, ratio_minmax=self.cutmix_minmax, correct_lam=self.correct_lam)
                    mixed[:, yl:yh, xl:xh] = batch[j][0][:, yl:yh, xl:xh]
                    lam_batch[i] = lam
                else:
                    mixed = mixed.astype(np.float32) * lam + batch[j][0].astype(np.float32) * (1 - lam)
                    np.rint(mixed, out=mixed)
            output[i] += torch.from_numpy(mixed.astype(np.uint8))
        if half:
            lam_batch = np.concatenate((lam_batch, np.ones(num_elem)))
        return torch.tensor(lam_batch).unsqueeze(1)

    def _mix_pair_collate(self, output, batch):
        batch_size = len(batch)
        lam_batch, use_cutmix = self._params_per_elem(batch_size // 2)
        for i in range(batch_size // 2):
            j = batch_size - i - 1
            lam = lam_batch[i]
            mixed_i = batch[i][0]
            mixed_j = batch[j][0]
            assert 0 <= lam <= 1.0
            if lam < 1.:
                if use_cutmix[i]:
                    (yl, yh, xl, xh), lam = cutmix_bbox_and_lam(
                        output.shape, lam, ratio_minmax=self.cutmix_minmax, correct_lam=self.correct_lam)
                    patch_i = mixed_i[:, yl:yh, xl:xh].copy()
                    mixed_i[:, yl:yh, xl:xh] = mixed_j[:, yl:yh, xl:xh]
                    mixed_j[:, yl:yh, xl:xh] = patch_i
                    lam_batch[i] = lam
                else:
                    mixed_temp = mixed_i.astype(np.float32) * lam + mixed_j.astype(np.float32) * (1 - lam)
                    mixed_j = mixed_j.astype(np.float32) * lam + mixed_i.astype(np.float32) * (1 - lam)
                    mixed_i = mixed_temp
                    np.rint(mixed_j, out=mixed_j)
                    np.rint(mixed_i, out=mixed_i)
            output[i] += torch.from_numpy(mixed_i.astype(np.uint8))
            output[j] += torch.from_numpy(mixed_j.astype(np.uint8))
        lam_batch = np.concatenate((lam_batch, lam_batch[::-1]))
        return torch.tensor(lam_batch).unsqueeze(1)

    def _mix_batch_collate(self, output, batch):
        batch_size = len(batch)
        lam, use_cutmix = self._params_per_batch()
        if use_cutmix:
            (yl, yh, xl, xh), lam = cutmix_bbox_and_lam(
                output.shape, lam, ratio_minmax=self.cutmix_minmax, correct_lam=self.correct_lam)
        for i in range(batch_size):
            j = batch_size - i - 1
            mixed = batch[i][0]
            if lam != 1.:
                if use_cutmix:
                    mixed = mixed.copy()  # don't want to modify the original while iterating
                    mixed[:, yl:yh, xl:xh] = batch[j][0][:, yl:yh, xl:xh]
                else:
                    mixed = mixed.astype(np.float32) * lam + batch[j][0].astype(np.float32) * (1 - lam)
                    np.rint(mixed, out=mixed)
            output[i] += torch.from_numpy(mixed.astype(np.uint8))
        return lam

    def __call__(self, batch, _=None):
        batch_size = len(batch)
        assert batch_size % 2 == 0, 'Batch size should be even when using this'
        half = 'half' in self.mode
        if half:
            batch_size //= 2
        output = torch.zeros((batch_size, *batch[0][0].shape), dtype=torch.uint8)
        if self.mode == 'elem' or self.mode == 'half':
            lam = self._mix_elem_collate(output, batch, half=half)
        elif self.mode == 'pair':
            lam = self._mix_pair_collate(output, batch)
        else:
            lam = self._mix_batch_collate(output, batch)
        
        target = torch.tensor([b[1] for b in batch], dtype=torch.int64)
        #target = mixup_target(target, self.num_classes, lam, self.label_smoothing)
        species_target = mixup_target(target[0], self.num_classes[0], lam, self.label_smoothing)
        family_target = mixup_target(target[1], self.num_classes[1], lam, self.label_smoothing)
        manu_target = mixup_target(target[2], self.num_classes[2], lam, self.label_smoothing)
        #target = target[:batch_size]
        return output, species_target[:batch_size], family_target[:batch_size], manu_target[:batch_size]
# Out:
# Writing cast_models/mixup_hier.py

# %%
# %%writefile cast_models/ewc.py

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
from torch.utils.data import DataLoader

class EWC(nn.Module):
    def __init__(self, args):
        super().__init__()
        self.args = args
        self.ewc_lambda = args.lamda
        self.online = args.online
        self.tasks_encountered = []
        self.fisher = {}
        self.optpar = {}

    def regularize(self, named_params):
        if not self.ewc_lambda:
            return torch.tensor(0.0, device=next(iter(dict(named_params).values())).device)
    
        net_loss = torch.tensor(0.0, device=next(iter(dict(named_params).values())).device)
        for task_id in self.tasks_encountered:
            for name, param in named_params:
                if name not in self.fisher[task_id]:
                    continue
                fisher = self.fisher[task_id][name]
                optpar = self.optpar[task_id][name]
                net_loss += (fisher * (param - optpar).pow(2)).sum()
        return 0.5 * self.ewc_lambda * net_loss


    def update_fisher_optpar(self, model, current_itr, dataset, sample_size, batch_size=64, consolidate=True):
        """Estimate Fisher Information and store optimal parameters"""
        if consolidate:
            if self.online:
                current_itr = 1
                self.tasks_encountered = [1]
            else:
                self.tasks_encountered.append(current_itr)

        model.eval()
        device = next(model.parameters()).device
        loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=0)

        grads = {name: [] for name, _ in model.named_parameters()}

        for i, batch in enumerate(loader):
            if i >= sample_size // batch_size:
                break

            x = batch["image"].to(device)
            y = batch["variant"].to(device)

            model.zero_grad()
            logits, _, _ = model(x, batch["segments"].to(device))
            log_probs = F.log_softmax(logits, dim=-1)
            loss = F.nll_loss(log_probs, y)
            loss.backward()

            for name, param in model.named_parameters():
                if param.grad is not None:
                    grads[name].append(param.grad.detach().clone().pow(2))

        self.fisher[current_itr] = {}
        self.optpar[current_itr] = {}

        for name, param in model.named_parameters():
            if name in grads and grads[name]:
                stacked = torch.stack(grads[name])
                self.fisher[current_itr][name] = stacked.mean(dim=0)
                self.optpar[current_itr][name] = param.detach().clone()
# Out:
# Writing cast_models/ewc.py

# %%
# %%writefile cast_models/losses.py
# Copyright (c) 2015-present, Facebook, Inc.
# ✅ Updated cast_models/losses.py to use CrossEntropyLoss (no soft targets)

import torch
from torch.nn import functional as F

class DistillationLoss(torch.nn.Module):
    """
    HCAST-compatible loss wrapper (default: no distillation).
    """
    def __init__(self, base_criterion: torch.nn.Module, teacher_model: torch.nn.Module,
                 distillation_type: str, alpha: float, tau: float):
        super().__init__()
        self.base_criterion = base_criterion
        self.teacher_model = teacher_model
        assert distillation_type in ['none', 'soft', 'hard']
        self.distillation_type = distillation_type
        self.alpha = alpha
        self.tau = tau

    def forward(self, inputs, outputs, labels):
        outputs_kd = None
        if not isinstance(outputs, torch.Tensor):
            outputs, outputs_kd = outputs

        base_loss = self.base_criterion(outputs, labels)

        if self.distillation_type == 'none':
            return base_loss

        if outputs_kd is None:
            raise ValueError("Distillation enabled but outputs_kd is None")

        with torch.no_grad():
            teacher_outputs = self.teacher_model(inputs)

        if self.distillation_type == 'soft':
            T = self.tau
            distill_loss = F.kl_div(
                F.log_softmax(outputs_kd / T, dim=1),
                F.softmax(teacher_outputs / T, dim=1),
                reduction='batchmean'
            ) * (T * T)
        else:  # hard distillation
            distill_loss = F.cross_entropy(outputs_kd, teacher_outputs.argmax(dim=1))

        return base_loss * (1 - self.alpha) + distill_loss * self.alpha
# Out:
# Writing cast_models/losses.py

# %%
import pandas as pd
import numpy as np
import os

# ✅ Base path
base_path = "/kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data"

# ✅ Load mapping files
def load_mapping(file_path, label_type):
    mapping = []
    with open(file_path, 'r') as f:
        for line in f:
            parts = line.strip().split(" ", 1)
            if len(parts) == 2:
                mapping.append((parts[0], parts[1]))
    return pd.DataFrame(mapping, columns=["image", label_type])

variant_df = load_mapping(f"{base_path}/images_variant_trainval.txt", "variant")
family_df = load_mapping(f"{base_path}/images_family_trainval.txt", "family")
maker_df = load_mapping(f"{base_path}/images_manufacturer_trainval.txt", "maker")

# ✅ Merge labels on 'image'
df = variant_df.merge(family_df, on="image").merge(maker_df, on="image")

# ✅ Group by variant to get canonical family & maker
hierarchy = df.groupby("variant")[["family", "maker"]].agg(lambda x: x.mode().iloc[0]).reset_index()

# ✅ Create ID maps
variant_to_id = {v: i for i, v in enumerate(hierarchy["variant"].sort_values().unique())}
family_to_id = {f: i for i, f in enumerate(hierarchy["family"].sort_values().unique())}
maker_to_id = {m: i for i, m in enumerate(hierarchy["maker"].sort_values().unique())}

# ✅ Map IDs
hierarchy["variant_id"] = hierarchy["variant"].map(variant_to_id)
hierarchy["family_id"] = hierarchy["family"].map(family_to_id)
hierarchy["maker_id"] = hierarchy["maker"].map(maker_to_id)

# ✅ Optional: Create lookup dicts for later use
variant_to_family = hierarchy.set_index("variant_id")["family_id"].to_dict()
variant_to_maker = hierarchy.set_index("variant_id")["maker_id"].to_dict()

# ✅ Save CSV
output_path = "/kaggle/working/hierarchy_full.csv"
hierarchy.to_csv(output_path, index=False)

# ✅ Confirm
print("✅ hierarchy_full.csv saved with columns:", hierarchy.columns.tolist())
print(f"🔢 Classes: {len(variant_to_id)} variants, {len(family_to_id)} families, {len(maker_to_id)} makers")
# Out:
# ✅ hierarchy_full.csv saved with columns: ['variant', 'family', 'maker', 'variant_id', 'family_id', 'maker_id']
# 🔢 Classes: 100 variants, 70 families, 30 makers

# %%
import os
import json
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import random
import numpy as np

from cast_models.aircraft_dataset import AircraftHCASTDataset
from cast_models.cast import cast_small
from cast_models.engine_hier import train_one_epoch
from cast_models.losses import DistillationLoss
from cast_models.mixup_hier import Mixup
from cast_models.ewc import EWC  # ✅ EWC import

# ✅ Soft Cross Entropy for soft labels
def soft_ce_loss(logits, targets):
    log_probs = torch.nn.functional.log_softmax(logits, dim=-1)
    return -(targets * log_probs).sum(dim=-1).mean()

# Reproducibility
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

class Args:
    lr = 5e-4
    epochs = 100
    warmup_epochs = 10
    weight_decay = 0.05
    num_workers = 4
    distillation_type = 'none'
    alpha = 0.5
    tau = 1.0
    bce_loss = False
    globalkl = True
    gk_weight = 1.5
    grow_head = True
    mixup = 0.6
    cutmix = 0.8
    lamda = 10.0  
    online = False  
    debug = True

args = Args()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

ewc = EWC(args).to(device)

class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0

    def step(self, loss):
        if loss < self.best_loss - self.min_delta:
            self.best_loss = loss
            self.counter = 0
            return False
        else:
            self.counter += 1
            return self.counter >= self.patience

class WarmupCosineScheduler:
    def __init__(self, optimizer, warmup_epochs, total_epochs):
        self.optimizer = optimizer
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.base_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=total_epochs - warmup_epochs)
        self.current_epoch = 0
        self.initial_lrs = [group['lr'] for group in optimizer.param_groups]

    def step(self):
        self.current_epoch += 1
        if self.current_epoch <= self.warmup_epochs:
            scale = self.current_epoch / self.warmup_epochs
            for i, group in enumerate(self.optimizer.param_groups):
                group['lr'] = self.initial_lrs[i] * scale
        else:
            self.base_scheduler.step()

with open("task_split.json", "r") as f:
    task_split = json.load(f)

transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandAugment(num_ops=9, magnitude=5),
    transforms.ColorJitter(0.4, 0.4, 0.4, 0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
])

full_dataset = AircraftHCASTDataset(
    image_dir="/kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images",
    label_file="hierarchy_full.csv",
    image_split_file="/kaggle/input/fgvc-aircraft/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_variant_trainval.txt",
    mapping_file="mapping.txt",
    transform=transform
)

args.nb_classes = [
    full_dataset.num_variants,
    full_dataset.num_families,
    full_dataset.num_makers
]

model = cast_small(nb_classes=args.nb_classes, init_num_classes=0).to(device)
seen_variants, seen_families, seen_makers = set(), set(), set()

class RemapLabels(torch.utils.data.Dataset):
    def __init__(self, subset, variant_map, family_map, maker_map):
        self.subset = subset
        self.variant_map = variant_map
        self.family_map = family_map
        self.maker_map = maker_map

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        item = self.subset[idx]
        item["variant"] = torch.tensor(self.variant_map[item["variant"].item()])
        item["family"] = torch.tensor(self.family_map[item["family"].item()])
        item["maker"] = torch.tensor(self.maker_map[item["maker"].item()])
        return item

acc1_list, acc5_list = [], []
fam_acc_list, manu_acc_list = [], []
sploss_list, fmloss_list, mfloss_list = [], [], []

for task_idx in range(1, 21):
    task_name = f"task_{task_idx}"
    task_variant_entries = task_split[task_name]
    task_variant_names = set(v["variant"] for v in task_variant_entries)

    new_variants = set()
    for i, name in enumerate(full_dataset.variant_names):
        variant_id = full_dataset.variants[i]
        if name in task_variant_names and variant_id not in seen_variants:
            new_variants.add(variant_id)

    task_indices = [i for i, v in enumerate(full_dataset.variants)
                    if v in seen_variants.union(new_variants)]
    task_dataset = Subset(full_dataset, task_indices)

    task_family_ids = set(full_dataset.families[i] for i in task_indices)
    task_maker_ids = set(full_dataset.makers[i] for i in task_indices)

    new_families = task_family_ids - seen_families
    new_makers = task_maker_ids - seen_makers

    if len(seen_variants.union(new_variants)) > model.head.num_classes:
        model.head.expand(len(seen_variants.union(new_variants)) - model.head.num_classes)
    if len(seen_families.union(new_families)) > model.family_head.num_classes:
        model.family_head.expand(len(seen_families.union(new_families)) - model.family_head.num_classes)
    if len(seen_makers.union(new_makers)) > model.manufacturer_head.num_classes:
        model.manufacturer_head.expand(len(seen_makers.union(new_makers)) - model.manufacturer_head.num_classes)

    seen_variants.update(new_variants)
    seen_families.update(new_families)
    seen_makers.update(new_makers)

    variant_id_map = {orig: i for i, orig in enumerate(sorted(seen_variants))}
    family_id_map = {orig: i for i, orig in enumerate(sorted(seen_families))}
    maker_id_map = {orig: i for i, orig in enumerate(sorted(seen_makers))}

    variant_to_family_matrix = torch.zeros((len(variant_id_map), len(family_id_map)), device=device)
    variant_to_maker_matrix = torch.zeros((len(variant_id_map), len(maker_id_map)), device=device)

    for v_orig, v_new in variant_id_map.items():
        try:
            idx = full_dataset.variants.index(v_orig)
            f_orig = full_dataset.families[idx]
            m_orig = full_dataset.makers[idx]
            f_new = family_id_map[f_orig]
            m_new = maker_id_map[m_orig]
            variant_to_family_matrix[v_new, f_new] = 1.0
            variant_to_maker_matrix[v_new, m_new] = 1.0
        except ValueError:
            continue

    task_dataset_remap = RemapLabels(task_dataset, variant_id_map, family_id_map, maker_id_map)

    train_loader = DataLoader(task_dataset_remap, batch_size=128, shuffle=True,
                              num_workers=args.num_workers, drop_last=True, pin_memory=True)

    print(f"\n🚀 Training {task_name} | {len(task_dataset)} samples")

    base_criterion = soft_ce_loss
    criterion = DistillationLoss(base_criterion, None, args.distillation_type, args.alpha, args.tau)
    optimizer = optim.AdamW(model.parameters(), lr=args.lr, weight_decay=args.weight_decay)
    lr_scheduler = WarmupCosineScheduler(optimizer, args.warmup_epochs, args.epochs)

    mixup_fn = Mixup(
        mixup_alpha=args.mixup,
        cutmix_alpha=args.cutmix,
        num_classes=[len(variant_id_map), len(family_id_map), len(maker_id_map)],
        label_smoothing=0.1,
        correct_lam=True,
        mode="batch"
    )

    early_stopper = EarlyStopping(patience=10, min_delta=0.001)

    for epoch in range(args.epochs):
        train_stats = train_one_epoch(
            model, criterion, train_loader, optimizer,
            device, epoch, loss_scaler=None,
            model_ema=None, mixup_fn=mixup_fn,
            set_training_mode=True, args=args,
            task_classes=len(variant_id_map) if epoch == 0 else None,
            variant_to_family_matrix=variant_to_family_matrix,
            variant_to_maker_matrix=variant_to_maker_matrix,
            ewc_loss_fn=ewc
        )

        lr_scheduler.step()

        # 🔍 Per-epoch metric print
        variant_acc = train_stats.get("acc1", 0)
        acc5 = train_stats.get("acc5", 0)
        fam_acc = train_stats.get("family_acc1", 0)
        manu_acc = train_stats.get("manu_acc1", 0)
        sploss = train_stats.get("sploss", 0)
        fmloss = train_stats.get("fmloss", 0)
        mfloss = train_stats.get("mfloss", 0)
        gkl = train_stats.get("globalkl_loss", 0)

        print(f"📊 Epoch {epoch+1}/{args.epochs} | "
              f"V@1: {variant_acc:.2f} | Top-5: {acc5:.2f} | "
              f"F@1: {fam_acc:.2f} | M@1: {manu_acc:.2f} | "
              f"V-Loss: {sploss:.4f} | F-Loss: {fmloss:.4f} | M-Loss: {mfloss:.4f} | "
              f"GKL: {gkl:.4f}")

        if early_stopper.step(sploss):
            print(f"🛑 Early stopping at epoch {epoch+1} due to no improvement in variant loss.")
            break

    ewc.update_fisher_optpar(
        model=model,
        current_itr=task_idx,
        dataset=task_dataset_remap,
        sample_size=512,
        batch_size=64,
        consolidate=True
    )

    acc1_list.append(variant_acc)
    acc5_list.append(acc5)
    fam_acc_list.append(fam_acc)
    manu_acc_list.append(manu_acc)
    sploss_list.append(sploss)
    fmloss_list.append(fmloss)
    mfloss_list.append(mfloss)

    print(f"\n✅ Task {task_idx} Completed")
    print(f"   ✈️ Variant Accuracy: {variant_acc:.2f}")
    print(f"   🎯 Top-5 Accuracy: {acc5:.2f}")
    print(f"   🏷️ Family Accuracy: {fam_acc:.2f}")
    print(f"   🏭 Manufacturer Accuracy: {manu_acc:.2f}")
    print(f"   🔻 Split Loss: {sploss:.4f}")
    print(f"   🔻 Family Loss: {fmloss:.4f}")
    print(f"   🔻 Manufacturer Loss: {mfloss:.4f}\n")

    torch.save(model.state_dict(), f"hcast_task{task_idx}.pth")
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# 🚀 Training task_1 | 333 samples
# 📊 Epoch 1/100 | V@1: 17.19 | Top-5: 100.00 | F@1: 15.23 | M@1: 27.34 | V-Loss: 2.6287 | F-Loss: 2.8897 | M-Loss: 2.2198 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 19.92 | Top-5: 100.00 | F@1: 26.95 | M@1: 19.92 | V-Loss: 2.4693 | F-Loss: 5.1523 | M-Loss: 3.7779 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 21.48 | Top-5: 100.00 | F@1: 20.70 | M@1: 19.53 | V-Loss: 2.1363 | F-Loss: 4.4399 | M-Loss: 2.5181 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 20.31 | Top-5: 100.00 | F@1: 18.75 | M@1: 29.69 | V-Loss: 1.8512 | F-Loss: 2.9244 | M-Loss: 1.8763 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 22.27 | Top-5: 100.00 | F@1: 21.48 | M@1: 41.80 | V-Loss: 2.2961 | F-Loss: 2.5544 | M-Loss: 1.6140 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 19.14 | Top-5: 100.00 | F@1: 18.75 | M@1: 25.78 | V-Loss: 2.2629 | F-Loss: 2.2045 | M-Loss: 1.4445 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 20.70 | Top-5: 100.00 | F@1: 17.58 | M@1: 38.28 | V-Loss: 1.9622 | F-Loss: 1.9490 | M-Loss: 1.3520 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 17.19 | Top-5: 100.00 | F@1: 19.53 | M@1: 37.89 | V-Loss: 2.2289 | F-Loss: 1.9862 | M-Loss: 1.3758 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 20.70 | Top-5: 100.00 | F@1: 22.27 | M@1: 19.92 | V-Loss: 1.8859 | F-Loss: 1.8305 | M-Loss: 1.4279 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 21.88 | Top-5: 100.00 | F@1: 21.88 | M@1: 26.17 | V-Loss: 2.2560 | F-Loss: 1.6827 | M-Loss: 1.3666 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 28.91 | Top-5: 100.00 | F@1: 22.66 | M@1: 41.02 | V-Loss: 1.7783 | F-Loss: 1.8372 | M-Loss: 1.3568 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 18.75 | Top-5: 100.00 | F@1: 21.48 | M@1: 40.62 | V-Loss: 2.1000 | F-Loss: 1.8829 | M-Loss: 1.3742 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 30.86 | Top-5: 100.00 | F@1: 24.61 | M@1: 37.11 | V-Loss: 1.7066 | F-Loss: 1.9239 | M-Loss: 1.3912 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 23.83 | Top-5: 100.00 | F@1: 21.09 | M@1: 39.06 | V-Loss: 1.7505 | F-Loss: 2.0166 | M-Loss: 1.3451 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 26.56 | Top-5: 100.00 | F@1: 25.78 | M@1: 40.62 | V-Loss: 1.6571 | F-Loss: 1.8802 | M-Loss: 1.3313 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 18.75 | Top-5: 100.00 | F@1: 19.92 | M@1: 42.19 | V-Loss: 1.6913 | F-Loss: 2.0174 | M-Loss: 1.3311 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 28.91 | Top-5: 100.00 | F@1: 18.36 | M@1: 40.62 | V-Loss: 1.6078 | F-Loss: 1.9266 | M-Loss: 1.3453 | GKL: 0.0000
# 📊 Epoch 18/100 | V@1: 25.78 | Top-5: 100.00 | F@1: 22.66 | M@1: 40.62 | V-Loss: 1.7084 | F-Loss: 1.7808 | M-Loss: 1.3346 | GKL: 0.0000
# 📊 Epoch 19/100 | V@1: 25.00 | Top-5: 100.00 | F@1: 25.39 | M@1: 38.28 | V-Loss: 1.7293 | F-Loss: 1.6469 | M-Loss: 1.3506 | GKL: 0.0000
# 📊 Epoch 20/100 | V@1: 25.39 | Top-5: 100.00 | F@1: 23.44 | M@1: 40.62 | V-Loss: 1.6512 | F-Loss: 1.6598 | M-Loss: 1.3285 | GKL: 0.0000
# 📊 Epoch 21/100 | V@1: 25.00 | Top-5: 100.00 | F@1: 22.66 | M@1: 41.41 | V-Loss: 1.6901 | F-Loss: 1.7152 | M-Loss: 1.3335 | GKL: 0.0000
# 📊 Epoch 22/100 | V@1: 27.34 | Top-5: 100.00 | F@1: 19.92 | M@1: 38.67 | V-Loss: 1.6448 | F-Loss: 1.7648 | M-Loss: 1.3244 | GKL: 0.0000
# 📊 Epoch 23/100 | V@1: 21.09 | Top-5: 100.00 | F@1: 17.97 | M@1: 39.84 | V-Loss: 1.6680 | F-Loss: 1.8115 | M-Loss: 1.3388 | GKL: 0.0000
# 📊 Epoch 24/100 | V@1: 23.05 | Top-5: 100.00 | F@1: 21.48 | M@1: 41.02 | V-Loss: 1.6420 | F-Loss: 1.7242 | M-Loss: 1.3109 | GKL: 0.0000
# 📊 Epoch 25/100 | V@1: 21.88 | Top-5: 100.00 | F@1: 20.70 | M@1: 38.67 | V-Loss: 1.7086 | F-Loss: 1.7132 | M-Loss: 1.3351 | GKL: 0.0000
# 📊 Epoch 26/100 | V@1: 30.47 | Top-5: 100.00 | F@1: 22.27 | M@1: 40.23 | V-Loss: 1.6260 | F-Loss: 1.7031 | M-Loss: 1.3125 | GKL: 0.0000
# 📊 Epoch 27/100 | V@1: 25.00 | Top-5: 100.00 | F@1: 24.61 | M@1: 39.84 | V-Loss: 1.5973 | F-Loss: 1.6597 | M-Loss: 1.3208 | GKL: 0.0000
# 📊 Epoch 28/100 | V@1: 23.44 | Top-5: 100.00 | F@1: 23.83 | M@1: 39.84 | V-Loss: 1.6041 | F-Loss: 1.7535 | M-Loss: 1.3193 | GKL: 0.0000
# 📊 Epoch 29/100 | V@1: 26.56 | Top-5: 100.00 | F@1: 24.61 | M@1: 41.80 | V-Loss: 1.5857 | F-Loss: 1.7165 | M-Loss: 1.3172 | GKL: 0.0000
# 📊 Epoch 30/100 | V@1: 26.95 | Top-5: 100.00 | F@1: 23.44 | M@1: 42.97 | V-Loss: 1.5902 | F-Loss: 1.6655 | M-Loss: 1.2992 | GKL: 0.0000
# 📊 Epoch 31/100 | V@1: 30.08 | Top-5: 100.00 | F@1: 26.56 | M@1: 41.02 | V-Loss: 1.5470 | F-Loss: 1.6684 | M-Loss: 1.2949 | GKL: 0.0000
# 📊 Epoch 32/100 | V@1: 27.73 | Top-5: 100.00 | F@1: 24.22 | M@1: 41.41 | V-Loss: 1.6173 | F-Loss: 1.7035 | M-Loss: 1.3162 | GKL: 0.0000
# 📊 Epoch 33/100 | V@1: 25.78 | Top-5: 100.00 | F@1: 23.05 | M@1: 39.06 | V-Loss: 1.5895 | F-Loss: 1.6485 | M-Loss: 1.3159 | GKL: 0.0000
# 📊 Epoch 34/100 | V@1: 19.14 | Top-5: 100.00 | F@1: 23.44 | M@1: 37.50 | V-Loss: 1.6044 | F-Loss: 1.6193 | M-Loss: 1.3226 | GKL: 0.0000
# 📊 Epoch 35/100 | V@1: 21.48 | Top-5: 100.00 | F@1: 19.92 | M@1: 33.98 | V-Loss: 1.6363 | F-Loss: 1.6735 | M-Loss: 1.3124 | GKL: 0.0000
# 📊 Epoch 36/100 | V@1: 22.27 | Top-5: 100.00 | F@1: 20.31 | M@1: 41.80 | V-Loss: 1.6201 | F-Loss: 1.6554 | M-Loss: 1.2886 | GKL: 0.0000
# 📊 Epoch 37/100 | V@1: 22.27 | Top-5: 100.00 | F@1: 21.09 | M@1: 38.67 | V-Loss: 1.6575 | F-Loss: 1.6607 | M-Loss: 1.3200 | GKL: 0.0000
# 📊 Epoch 38/100 | V@1: 26.17 | Top-5: 100.00 | F@1: 22.27 | M@1: 43.75 | V-Loss: 1.6359 | F-Loss: 1.7112 | M-Loss: 1.3023 | GKL: 0.0000
# 📊 Epoch 39/100 | V@1: 23.44 | Top-5: 100.00 | F@1: 20.70 | M@1: 37.89 | V-Loss: 1.5500 | F-Loss: 1.6260 | M-Loss: 1.2959 | GKL: 0.0000
# 📊 Epoch 40/100 | V@1: 25.39 | Top-5: 100.00 | F@1: 25.39 | M@1: 42.97 | V-Loss: 1.5715 | F-Loss: 1.6404 | M-Loss: 1.2984 | GKL: 0.0000
# 📊 Epoch 41/100 | V@1: 23.05 | Top-5: 100.00 | F@1: 24.22 | M@1: 41.41 | V-Loss: 1.5460 | F-Loss: 1.6287 | M-Loss: 1.2833 | GKL: 0.0000
# 🛑 Early stopping at epoch 41 due to no improvement in variant loss.
#
# ✅ Task 1 Completed
#    ✈️ Variant Accuracy: 23.05
#    🎯 Top-5 Accuracy: 100.00
#    🏷️ Family Accuracy: 24.22
#    🏭 Manufacturer Accuracy: 41.41
#    🔻 Split Loss: 1.5460
#    🔻 Family Loss: 1.6287
#    🔻 Manufacturer Loss: 1.2833
#
#
# 🚀 Training task_2 | 667 samples
# 📊 Epoch 1/100 | V@1: 10.00 | Top-5: 48.59 | F@1: 9.84 | M@1: 25.16 | V-Loss: 3.2374 | F-Loss: 9.9977 | M-Loss: 1.9650 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 10.31 | Top-5: 48.75 | F@1: 10.94 | M@1: 32.66 | V-Loss: 2.9110 | F-Loss: 4.7325 | M-Loss: 1.7961 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 13.28 | Top-5: 55.47 | F@1: 9.69 | M@1: 34.38 | V-Loss: 2.6078 | F-Loss: 3.3165 | M-Loss: 1.7075 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 10.16 | Top-5: 51.09 | F@1: 10.47 | M@1: 36.72 | V-Loss: 2.5222 | F-Loss: 2.8733 | M-Loss: 1.7141 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 10.47 | Top-5: 52.97 | F@1: 9.69 | M@1: 38.28 | V-Loss: 2.4888 | F-Loss: 2.5893 | M-Loss: 1.6568 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 10.47 | Top-5: 51.88 | F@1: 10.31 | M@1: 39.69 | V-Loss: 2.4573 | F-Loss: 2.4633 | M-Loss: 1.6513 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 9.69 | Top-5: 52.19 | F@1: 11.88 | M@1: 38.75 | V-Loss: 2.4287 | F-Loss: 2.3834 | M-Loss: 1.6624 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 11.25 | Top-5: 49.69 | F@1: 11.72 | M@1: 39.06 | V-Loss: 2.4161 | F-Loss: 2.3712 | M-Loss: 1.6418 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 11.72 | Top-5: 52.34 | F@1: 13.12 | M@1: 39.38 | V-Loss: 2.4070 | F-Loss: 2.3732 | M-Loss: 1.6516 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 12.66 | Top-5: 53.59 | F@1: 8.12 | M@1: 40.47 | V-Loss: 2.3958 | F-Loss: 2.4725 | M-Loss: 1.6323 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 10.78 | Top-5: 55.47 | F@1: 13.75 | M@1: 39.53 | V-Loss: 2.3864 | F-Loss: 2.3951 | M-Loss: 1.6401 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 10.47 | Top-5: 52.50 | F@1: 10.47 | M@1: 39.38 | V-Loss: 2.4121 | F-Loss: 2.4972 | M-Loss: 1.6499 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 10.47 | Top-5: 54.22 | F@1: 11.09 | M@1: 40.16 | V-Loss: 2.3443 | F-Loss: 2.3861 | M-Loss: 1.6414 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 10.62 | Top-5: 51.72 | F@1: 10.16 | M@1: 40.31 | V-Loss: 2.3469 | F-Loss: 2.3615 | M-Loss: 1.6369 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 13.12 | Top-5: 53.44 | F@1: 12.66 | M@1: 38.91 | V-Loss: 2.3249 | F-Loss: 2.3517 | M-Loss: 1.6299 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 13.44 | Top-5: 55.94 | F@1: 12.19 | M@1: 40.31 | V-Loss: 2.3132 | F-Loss: 2.3146 | M-Loss: 1.6235 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 16.88 | Top-5: 63.75 | F@1: 16.41 | M@1: 40.31 | V-Loss: 2.2610 | F-Loss: 2.2836 | M-Loss: 1.6080 | GKL: 0.0000
# 📊 Epoch 18/100 | V@1: 13.12 | Top-5: 52.97 | F@1: 10.78 | M@1: 38.44 | V-Loss: 2.3322 | F-Loss: 2.3480 | M-Loss: 1.6416 | GKL: 0.0000
# 📊 Epoch 19/100 | V@1: 12.50 | Top-5: 52.81 | F@1: 9.53 | M@1: 40.00 | V-Loss: 2.3298 | F-Loss: 2.3540 | M-Loss: 1.6450 | GKL: 0.0000
# 📊 Epoch 20/100 | V@1: 12.97 | Top-5: 56.25 | F@1: 12.81 | M@1: 40.94 | V-Loss: 2.3362 | F-Loss: 2.3517 | M-Loss: 1.6473 | GKL: 0.0000
# 📊 Epoch 21/100 | V@1: 12.34 | Top-5: 55.62 | F@1: 15.00 | M@1: 39.06 | V-Loss: 2.3676 | F-Loss: 2.3549 | M-Loss: 1.6513 | GKL: 0.0000
# 📊 Epoch 22/100 | V@1: 12.34 | Top-5: 56.09 | F@1: 12.66 | M@1: 40.00 | V-Loss: 2.3469 | F-Loss: 2.3103 | M-Loss: 1.6454 | GKL: 0.0000
# 📊 Epoch 23/100 | V@1: 11.56 | Top-5: 56.88 | F@1: 11.56 | M@1: 40.16 | V-Loss: 2.3387 | F-Loss: 2.3293 | M-Loss: 1.6218 | GKL: 0.0000
# 📊 Epoch 24/100 | V@1: 14.69 | Top-5: 60.31 | F@1: 12.34 | M@1: 40.31 | V-Loss: 2.3095 | F-Loss: 2.2958 | M-Loss: 1.6198 | GKL: 0.0000
# 📊 Epoch 25/100 | V@1: 13.91 | Top-5: 56.56 | F@1: 12.66 | M@1: 39.38 | V-Loss: 2.3207 | F-Loss: 2.3029 | M-Loss: 1.6419 | GKL: 0.0000
# 📊 Epoch 26/100 | V@1: 12.03 | Top-5: 57.66 | F@1: 11.25 | M@1: 40.16 | V-Loss: 2.3061 | F-Loss: 2.3132 | M-Loss: 1.6368 | GKL: 0.0000
# 📊 Epoch 27/100 | V@1: 14.06 | Top-5: 57.97 | F@1: 16.25 | M@1: 40.47 | V-Loss: 2.3093 | F-Loss: 2.3144 | M-Loss: 1.6163 | GKL: 0.0000
# 🛑 Early stopping at epoch 27 due to no improvement in variant loss.
#
# ✅ Task 2 Completed
#    ✈️ Variant Accuracy: 14.06
#    🎯 Top-5 Accuracy: 57.97
#    🏷️ Family Accuracy: 16.25
#    🏭 Manufacturer Accuracy: 40.47
#    🔻 Split Loss: 2.3093
#    🔻 Family Loss: 2.3144
#    🔻 Manufacturer Loss: 1.6163
#
#
# 🚀 Training task_3 | 1001 samples
# 📊 Epoch 1/100 | V@1: 7.03 | Top-5: 31.70 | F@1: 7.37 | M@1: 30.02 | V-Loss: 3.4517 | F-Loss: 4.0349 | M-Loss: 2.1115 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 6.36 | Top-5: 31.70 | F@1: 9.04 | M@1: 32.59 | V-Loss: 3.3812 | F-Loss: 3.2237 | M-Loss: 2.0530 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 7.70 | Top-5: 35.71 | F@1: 8.37 | M@1: 33.82 | V-Loss: 2.9584 | F-Loss: 2.9607 | M-Loss: 2.0218 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 7.03 | Top-5: 32.48 | F@1: 7.14 | M@1: 33.37 | V-Loss: 2.8503 | F-Loss: 2.8507 | M-Loss: 2.0245 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 7.14 | Top-5: 37.50 | F@1: 8.37 | M@1: 32.81 | V-Loss: 2.7906 | F-Loss: 2.7789 | M-Loss: 2.0361 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 7.03 | Top-5: 33.82 | F@1: 7.92 | M@1: 33.48 | V-Loss: 2.7782 | F-Loss: 2.7559 | M-Loss: 2.0201 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 7.14 | Top-5: 35.38 | F@1: 8.48 | M@1: 33.04 | V-Loss: 2.7856 | F-Loss: 2.7528 | M-Loss: 2.0293 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 7.48 | Top-5: 33.82 | F@1: 7.37 | M@1: 32.92 | V-Loss: 2.8124 | F-Loss: 2.8368 | M-Loss: 2.0223 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 9.71 | Top-5: 36.83 | F@1: 6.58 | M@1: 33.71 | V-Loss: 2.7603 | F-Loss: 2.7968 | M-Loss: 2.0106 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 9.04 | Top-5: 38.06 | F@1: 8.82 | M@1: 33.59 | V-Loss: 2.7523 | F-Loss: 2.7586 | M-Loss: 2.0192 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 8.48 | Top-5: 39.84 | F@1: 8.04 | M@1: 32.48 | V-Loss: 2.7365 | F-Loss: 2.7522 | M-Loss: 2.0229 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 8.26 | Top-5: 40.96 | F@1: 7.92 | M@1: 32.92 | V-Loss: 2.7234 | F-Loss: 2.7634 | M-Loss: 2.0107 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 9.15 | Top-5: 38.62 | F@1: 9.04 | M@1: 33.04 | V-Loss: 2.7581 | F-Loss: 2.7563 | M-Loss: 2.0155 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 9.93 | Top-5: 38.50 | F@1: 8.15 | M@1: 33.48 | V-Loss: 2.7399 | F-Loss: 2.7810 | M-Loss: 2.0236 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 8.04 | Top-5: 38.84 | F@1: 9.82 | M@1: 32.81 | V-Loss: 2.7308 | F-Loss: 2.7241 | M-Loss: 2.0206 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 8.71 | Top-5: 36.94 | F@1: 8.37 | M@1: 33.59 | V-Loss: 2.7391 | F-Loss: 2.7351 | M-Loss: 2.0168 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 8.48 | Top-5: 38.50 | F@1: 7.14 | M@1: 32.81 | V-Loss: 2.7140 | F-Loss: 2.7274 | M-Loss: 2.0279 | GKL: 0.0000
# 📊 Epoch 18/100 | V@1: 8.37 | Top-5: 36.38 | F@1: 9.71 | M@1: 32.48 | V-Loss: 2.7018 | F-Loss: 2.7055 | M-Loss: 2.0136 | GKL: 0.0000
# 📊 Epoch 19/100 | V@1: 9.49 | Top-5: 42.63 | F@1: 9.26 | M@1: 33.04 | V-Loss: 2.7197 | F-Loss: 2.7256 | M-Loss: 2.0122 | GKL: 0.0000
# 📊 Epoch 20/100 | V@1: 9.04 | Top-5: 42.63 | F@1: 9.38 | M@1: 33.04 | V-Loss: 2.7023 | F-Loss: 2.7442 | M-Loss: 2.0196 | GKL: 0.0000
# 📊 Epoch 21/100 | V@1: 10.38 | Top-5: 38.95 | F@1: 9.04 | M@1: 33.48 | V-Loss: 2.7024 | F-Loss: 2.7407 | M-Loss: 2.0039 | GKL: 0.0000
# 📊 Epoch 22/100 | V@1: 9.15 | Top-5: 37.28 | F@1: 8.37 | M@1: 32.48 | V-Loss: 2.6909 | F-Loss: 2.7110 | M-Loss: 2.0148 | GKL: 0.0000
# 📊 Epoch 23/100 | V@1: 9.93 | Top-5: 41.85 | F@1: 8.37 | M@1: 33.82 | V-Loss: 2.6671 | F-Loss: 2.6895 | M-Loss: 1.9901 | GKL: 0.0000
# 📊 Epoch 24/100 | V@1: 11.50 | Top-5: 44.42 | F@1: 10.94 | M@1: 32.14 | V-Loss: 2.6354 | F-Loss: 2.6823 | M-Loss: 1.9812 | GKL: 0.0000
# 📊 Epoch 25/100 | V@1: 13.84 | Top-5: 49.67 | F@1: 12.05 | M@1: 33.04 | V-Loss: 2.6341 | F-Loss: 2.6654 | M-Loss: 1.9803 | GKL: 0.0000
# 📊 Epoch 26/100 | V@1: 12.39 | Top-5: 40.96 | F@1: 9.93 | M@1: 34.38 | V-Loss: 2.6422 | F-Loss: 2.6730 | M-Loss: 1.9717 | GKL: 0.0000
# 📊 Epoch 27/100 | V@1: 11.27 | Top-5: 43.30 | F@1: 11.05 | M@1: 32.92 | V-Loss: 2.6538 | F-Loss: 2.6831 | M-Loss: 1.9711 | GKL: 0.0000
# 📊 Epoch 28/100 | V@1: 11.38 | Top-5: 41.29 | F@1: 10.49 | M@1: 33.71 | V-Loss: 2.6966 | F-Loss: 2.7141 | M-Loss: 1.9992 | GKL: 0.0000
# 📊 Epoch 29/100 | V@1: 10.83 | Top-5: 43.08 | F@1: 10.16 | M@1: 33.26 | V-Loss: 2.6620 | F-Loss: 2.6936 | M-Loss: 1.9765 | GKL: 0.0000
# 📊 Epoch 30/100 | V@1: 10.94 | Top-5: 45.98 | F@1: 10.16 | M@1: 32.59 | V-Loss: 2.6838 | F-Loss: 2.7161 | M-Loss: 2.0030 | GKL: 0.0000
# 📊 Epoch 31/100 | V@1: 13.84 | Top-5: 47.88 | F@1: 10.60 | M@1: 32.92 | V-Loss: 2.6544 | F-Loss: 2.6677 | M-Loss: 1.9865 | GKL: 0.0000
# 📊 Epoch 32/100 | V@1: 12.39 | Top-5: 47.99 | F@1: 11.61 | M@1: 33.15 | V-Loss: 2.6723 | F-Loss: 2.6791 | M-Loss: 1.9894 | GKL: 0.0000
# 📊 Epoch 33/100 | V@1: 12.72 | Top-5: 49.67 | F@1: 11.94 | M@1: 33.48 | V-Loss: 2.6065 | F-Loss: 2.6077 | M-Loss: 1.9445 | GKL: 0.0000
# 📊 Epoch 34/100 | V@1: 10.49 | Top-5: 41.85 | F@1: 11.38 | M@1: 31.47 | V-Loss: 2.6641 | F-Loss: 2.6717 | M-Loss: 1.9861 | GKL: 0.0000
# 📊 Epoch 35/100 | V@1: 9.82 | Top-5: 42.63 | F@1: 9.93 | M@1: 31.70 | V-Loss: 2.6564 | F-Loss: 2.6633 | M-Loss: 1.9759 | GKL: 0.0000
# 📊 Epoch 36/100 | V@1: 10.49 | Top-5: 44.31 | F@1: 9.60 | M@1: 33.59 | V-Loss: 2.6270 | F-Loss: 2.6464 | M-Loss: 1.9561 | GKL: 0.0000
# 📊 Epoch 37/100 | V@1: 13.73 | Top-5: 51.12 | F@1: 13.28 | M@1: 33.71 | V-Loss: 2.6375 | F-Loss: 2.6538 | M-Loss: 1.9702 | GKL: 0.0000
# 📊 Epoch 38/100 | V@1: 11.50 | Top-5: 45.20 | F@1: 11.61 | M@1: 33.59 | V-Loss: 2.6135 | F-Loss: 2.6441 | M-Loss: 1.9478 | GKL: 0.0000
# 📊 Epoch 39/100 | V@1: 12.61 | Top-5: 44.20 | F@1: 11.94 | M@1: 33.93 | V-Loss: 2.6256 | F-Loss: 2.6488 | M-Loss: 1.9633 | GKL: 0.0000
# 📊 Epoch 40/100 | V@1: 13.39 | Top-5: 51.00 | F@1: 12.83 | M@1: 33.59 | V-Loss: 2.5652 | F-Loss: 2.5816 | M-Loss: 1.9170 | GKL: 0.0000
# 📊 Epoch 41/100 | V@1: 11.38 | Top-5: 50.45 | F@1: 10.60 | M@1: 32.48 | V-Loss: 2.5839 | F-Loss: 2.6057 | M-Loss: 1.9542 | GKL: 0.0000
# 📊 Epoch 42/100 | V@1: 13.73 | Top-5: 48.21 | F@1: 13.28 | M@1: 34.04 | V-Loss: 2.6073 | F-Loss: 2.6265 | M-Loss: 1.9491 | GKL: 0.0000
# 📊 Epoch 43/100 | V@1: 13.28 | Top-5: 45.76 | F@1: 11.16 | M@1: 32.59 | V-Loss: 2.6166 | F-Loss: 2.6458 | M-Loss: 1.9651 | GKL: 0.0000
# 📊 Epoch 44/100 | V@1: 13.84 | Top-5: 46.09 | F@1: 12.50 | M@1: 33.26 | V-Loss: 2.6115 | F-Loss: 2.6275 | M-Loss: 1.9625 | GKL: 0.0000
# 📊 Epoch 45/100 | V@1: 12.50 | Top-5: 50.00 | F@1: 11.38 | M@1: 33.82 | V-Loss: 2.5850 | F-Loss: 2.6180 | M-Loss: 1.9342 | GKL: 0.0000
# 📊 Epoch 46/100 | V@1: 14.06 | Top-5: 49.22 | F@1: 13.28 | M@1: 33.37 | V-Loss: 2.5567 | F-Loss: 2.5780 | M-Loss: 1.9239 | GKL: 0.0000
# 📊 Epoch 47/100 | V@1: 16.07 | Top-5: 54.80 | F@1: 14.73 | M@1: 32.70 | V-Loss: 2.5042 | F-Loss: 2.5142 | M-Loss: 1.9112 | GKL: 0.0000
# 📊 Epoch 48/100 | V@1: 12.50 | Top-5: 47.77 | F@1: 12.95 | M@1: 31.70 | V-Loss: 2.5333 | F-Loss: 2.5400 | M-Loss: 1.9271 | GKL: 0.0000
# 📊 Epoch 49/100 | V@1: 13.06 | Top-5: 49.78 | F@1: 14.73 | M@1: 32.81 | V-Loss: 2.6162 | F-Loss: 2.6302 | M-Loss: 1.9588 | GKL: 0.0000
# 📊 Epoch 50/100 | V@1: 10.83 | Top-5: 42.30 | F@1: 9.93 | M@1: 33.37 | V-Loss: 2.6295 | F-Loss: 2.6445 | M-Loss: 1.9649 | GKL: 0.0000
# 📊 Epoch 51/100 | V@1: 20.65 | Top-5: 60.94 | F@1: 19.42 | M@1: 34.60 | V-Loss: 2.5402 | F-Loss: 2.5686 | M-Loss: 1.9251 | GKL: 0.0000
# 📊 Epoch 52/100 | V@1: 18.53 | Top-5: 57.70 | F@1: 16.52 | M@1: 34.26 | V-Loss: 2.5263 | F-Loss: 2.5390 | M-Loss: 1.9045 | GKL: 0.0000
# 📊 Epoch 53/100 | V@1: 13.50 | Top-5: 45.87 | F@1: 12.72 | M@1: 34.60 | V-Loss: 2.5303 | F-Loss: 2.5465 | M-Loss: 1.8951 | GKL: 0.0000
# 📊 Epoch 54/100 | V@1: 13.17 | Top-5: 47.99 | F@1: 13.39 | M@1: 32.70 | V-Loss: 2.5567 | F-Loss: 2.5696 | M-Loss: 1.9142 | GKL: 0.0000
# 📊 Epoch 55/100 | V@1: 14.73 | Top-5: 50.56 | F@1: 14.29 | M@1: 34.38 | V-Loss: 2.5910 | F-Loss: 2.6056 | M-Loss: 1.9426 | GKL: 0.0000
# 📊 Epoch 56/100 | V@1: 21.09 | Top-5: 62.61 | F@1: 19.20 | M@1: 34.93 | V-Loss: 2.5168 | F-Loss: 2.5326 | M-Loss: 1.9025 | GKL: 0.0000
# 📊 Epoch 57/100 | V@1: 19.98 | Top-5: 60.83 | F@1: 19.53 | M@1: 36.38 | V-Loss: 2.5077 | F-Loss: 2.5199 | M-Loss: 1.8850 | GKL: 0.0000
# 🛑 Early stopping at epoch 57 due to no improvement in variant loss.
#
# ✅ Task 3 Completed
#    ✈️ Variant Accuracy: 19.98
#    🎯 Top-5 Accuracy: 60.83
#    🏷️ Family Accuracy: 19.53
#    🏭 Manufacturer Accuracy: 36.38
#    🔻 Split Loss: 2.5077
#    🔻 Family Loss: 2.5199
#    🔻 Manufacturer Loss: 1.8850
#
#
# 🚀 Training task_4 | 1335 samples
# 📊 Epoch 1/100 | V@1: 6.56 | Top-5: 30.47 | F@1: 4.84 | M@1: 23.98 | V-Loss: 3.2755 | F-Loss: 4.1023 | M-Loss: 2.3989 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 9.84 | Top-5: 35.00 | F@1: 7.58 | M@1: 25.00 | V-Loss: 2.9892 | F-Loss: 3.1694 | M-Loss: 2.3264 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 10.39 | Top-5: 38.36 | F@1: 7.89 | M@1: 25.00 | V-Loss: 2.9265 | F-Loss: 2.9913 | M-Loss: 2.3034 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 9.53 | Top-5: 37.97 | F@1: 9.77 | M@1: 26.17 | V-Loss: 2.8868 | F-Loss: 2.8949 | M-Loss: 2.2770 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 10.70 | Top-5: 43.12 | F@1: 9.84 | M@1: 25.47 | V-Loss: 2.9082 | F-Loss: 2.9334 | M-Loss: 2.2921 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 12.89 | Top-5: 42.50 | F@1: 11.80 | M@1: 26.17 | V-Loss: 2.8294 | F-Loss: 2.8638 | M-Loss: 2.2521 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 15.16 | Top-5: 51.25 | F@1: 12.73 | M@1: 25.86 | V-Loss: 2.8122 | F-Loss: 2.8623 | M-Loss: 2.2504 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 12.34 | Top-5: 40.23 | F@1: 11.48 | M@1: 24.69 | V-Loss: 2.8735 | F-Loss: 2.9034 | M-Loss: 2.2405 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 10.94 | Top-5: 41.25 | F@1: 11.09 | M@1: 23.75 | V-Loss: 2.8709 | F-Loss: 2.8970 | M-Loss: 2.2570 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 10.55 | Top-5: 38.98 | F@1: 9.84 | M@1: 24.92 | V-Loss: 2.8536 | F-Loss: 2.8687 | M-Loss: 2.2284 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 10.62 | Top-5: 40.31 | F@1: 10.47 | M@1: 25.23 | V-Loss: 2.8612 | F-Loss: 2.8763 | M-Loss: 2.2370 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 12.50 | Top-5: 39.77 | F@1: 11.56 | M@1: 25.31 | V-Loss: 2.9123 | F-Loss: 2.9247 | M-Loss: 2.2753 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 10.70 | Top-5: 38.36 | F@1: 10.86 | M@1: 23.83 | V-Loss: 2.8242 | F-Loss: 2.8359 | M-Loss: 2.2056 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 15.31 | Top-5: 46.48 | F@1: 14.53 | M@1: 28.05 | V-Loss: 2.7588 | F-Loss: 2.7873 | M-Loss: 2.1682 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 11.25 | Top-5: 43.28 | F@1: 11.64 | M@1: 27.11 | V-Loss: 2.8071 | F-Loss: 2.8212 | M-Loss: 2.1936 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 15.86 | Top-5: 52.50 | F@1: 15.86 | M@1: 32.11 | V-Loss: 2.7973 | F-Loss: 2.8003 | M-Loss: 2.1662 | GKL: 0.0000
# 📊 Epoch 18/100 | V@1: 14.69 | Top-5: 49.92 | F@1: 14.45 | M@1: 26.72 | V-Loss: 2.8071 | F-Loss: 2.8346 | M-Loss: 2.2139 | GKL: 0.0000
# 📊 Epoch 19/100 | V@1: 9.69 | Top-5: 35.23 | F@1: 8.05 | M@1: 23.59 | V-Loss: 2.7430 | F-Loss: 2.7874 | M-Loss: 2.1588 | GKL: 0.0000
# 📊 Epoch 20/100 | V@1: 18.98 | Top-5: 51.80 | F@1: 17.34 | M@1: 28.52 | V-Loss: 2.7433 | F-Loss: 2.7700 | M-Loss: 2.1547 | GKL: 0.0000
# 📊 Epoch 21/100 | V@1: 12.03 | Top-5: 39.06 | F@1: 11.25 | M@1: 24.61 | V-Loss: 2.7144 | F-Loss: 2.7329 | M-Loss: 2.1301 | GKL: 0.0000
# 📊 Epoch 22/100 | V@1: 13.12 | Top-5: 44.84 | F@1: 12.97 | M@1: 26.02 | V-Loss: 2.7841 | F-Loss: 2.7988 | M-Loss: 2.1890 | GKL: 0.0000
# 📊 Epoch 23/100 | V@1: 15.62 | Top-5: 45.00 | F@1: 15.94 | M@1: 26.17 | V-Loss: 2.7508 | F-Loss: 2.7573 | M-Loss: 2.1560 | GKL: 0.0000
# 📊 Epoch 24/100 | V@1: 16.56 | Top-5: 48.52 | F@1: 15.70 | M@1: 27.03 | V-Loss: 2.6186 | F-Loss: 2.6427 | M-Loss: 2.0721 | GKL: 0.0000
# 📊 Epoch 25/100 | V@1: 12.66 | Top-5: 42.34 | F@1: 11.64 | M@1: 26.80 | V-Loss: 2.7610 | F-Loss: 2.7895 | M-Loss: 2.1658 | GKL: 0.0000
# 📊 Epoch 26/100 | V@1: 16.09 | Top-5: 53.98 | F@1: 16.02 | M@1: 28.28 | V-Loss: 2.7895 | F-Loss: 2.8050 | M-Loss: 2.1878 | GKL: 0.0000
# 📊 Epoch 27/100 | V@1: 13.44 | Top-5: 43.28 | F@1: 14.06 | M@1: 27.19 | V-Loss: 2.6891 | F-Loss: 2.7051 | M-Loss: 2.1120 | GKL: 0.0000
# 📊 Epoch 28/100 | V@1: 16.64 | Top-5: 52.11 | F@1: 17.34 | M@1: 28.52 | V-Loss: 2.8149 | F-Loss: 2.8226 | M-Loss: 2.1963 | GKL: 0.0000
# 📊 Epoch 29/100 | V@1: 19.06 | Top-5: 55.47 | F@1: 18.59 | M@1: 30.23 | V-Loss: 2.7752 | F-Loss: 2.7973 | M-Loss: 2.1763 | GKL: 0.0000
# 📊 Epoch 30/100 | V@1: 16.48 | Top-5: 50.62 | F@1: 17.27 | M@1: 28.98 | V-Loss: 2.7192 | F-Loss: 2.7307 | M-Loss: 2.1365 | GKL: 0.0000
# 📊 Epoch 31/100 | V@1: 16.80 | Top-5: 52.73 | F@1: 17.58 | M@1: 30.78 | V-Loss: 2.6926 | F-Loss: 2.7085 | M-Loss: 2.1223 | GKL: 0.0000
# 📊 Epoch 32/100 | V@1: 16.41 | Top-5: 46.88 | F@1: 17.19 | M@1: 27.19 | V-Loss: 2.6745 | F-Loss: 2.6911 | M-Loss: 2.0843 | GKL: 0.0000
# 📊 Epoch 33/100 | V@1: 18.98 | Top-5: 53.12 | F@1: 18.36 | M@1: 30.08 | V-Loss: 2.5464 | F-Loss: 2.5785 | M-Loss: 2.0089 | GKL: 0.0000
# 📊 Epoch 34/100 | V@1: 24.61 | Top-5: 59.69 | F@1: 23.67 | M@1: 34.45 | V-Loss: 2.4994 | F-Loss: 2.5189 | M-Loss: 1.9795 | GKL: 0.0000
# 📊 Epoch 35/100 | V@1: 15.70 | Top-5: 47.11 | F@1: 14.22 | M@1: 27.19 | V-Loss: 2.6363 | F-Loss: 2.6640 | M-Loss: 2.0817 | GKL: 0.0000
# 📊 Epoch 36/100 | V@1: 17.89 | Top-5: 48.59 | F@1: 17.19 | M@1: 29.53 | V-Loss: 2.6884 | F-Loss: 2.7219 | M-Loss: 2.1122 | GKL: 0.0000
# 📊 Epoch 37/100 | V@1: 22.34 | Top-5: 55.62 | F@1: 21.95 | M@1: 31.02 | V-Loss: 2.6165 | F-Loss: 2.6465 | M-Loss: 2.0752 | GKL: 0.0000
# 📊 Epoch 38/100 | V@1: 18.20 | Top-5: 49.22 | F@1: 17.34 | M@1: 27.27 | V-Loss: 2.5943 | F-Loss: 2.6269 | M-Loss: 2.0496 | GKL: 0.0000
# 📊 Epoch 39/100 | V@1: 25.08 | Top-5: 61.80 | F@1: 24.45 | M@1: 35.62 | V-Loss: 2.5980 | F-Loss: 2.6161 | M-Loss: 2.0551 | GKL: 0.0000
# 📊 Epoch 40/100 | V@1: 23.75 | Top-5: 60.23 | F@1: 23.52 | M@1: 34.22 | V-Loss: 2.5873 | F-Loss: 2.6065 | M-Loss: 2.0487 | GKL: 0.0000
# 📊 Epoch 41/100 | V@1: 21.95 | Top-5: 56.88 | F@1: 22.58 | M@1: 31.95 | V-Loss: 2.5184 | F-Loss: 2.5417 | M-Loss: 1.9888 | GKL: 0.0000
# 📊 Epoch 42/100 | V@1: 23.05 | Top-5: 59.06 | F@1: 23.44 | M@1: 36.41 | V-Loss: 2.5595 | F-Loss: 2.5734 | M-Loss: 2.0260 | GKL: 0.0000
# 📊 Epoch 43/100 | V@1: 24.22 | Top-5: 59.30 | F@1: 24.84 | M@1: 34.38 | V-Loss: 2.5502 | F-Loss: 2.5660 | M-Loss: 2.0021 | GKL: 0.0000
# 📊 Epoch 44/100 | V@1: 15.23 | Top-5: 46.41 | F@1: 15.47 | M@1: 25.86 | V-Loss: 2.4160 | F-Loss: 2.4320 | M-Loss: 1.9178 | GKL: 0.0000
# 📊 Epoch 45/100 | V@1: 29.14 | Top-5: 65.78 | F@1: 28.20 | M@1: 39.22 | V-Loss: 2.4232 | F-Loss: 2.4388 | M-Loss: 1.9173 | GKL: 0.0000
# 📊 Epoch 46/100 | V@1: 31.56 | Top-5: 67.89 | F@1: 30.94 | M@1: 40.78 | V-Loss: 2.3802 | F-Loss: 2.4025 | M-Loss: 1.8773 | GKL: 0.0000
# 📊 Epoch 47/100 | V@1: 28.36 | Top-5: 60.70 | F@1: 27.58 | M@1: 35.78 | V-Loss: 2.5059 | F-Loss: 2.5161 | M-Loss: 1.9764 | GKL: 0.0000
# 📊 Epoch 48/100 | V@1: 28.83 | Top-5: 61.64 | F@1: 27.89 | M@1: 37.97 | V-Loss: 2.5003 | F-Loss: 2.5211 | M-Loss: 1.9848 | GKL: 0.0000
# 📊 Epoch 49/100 | V@1: 23.75 | Top-5: 56.64 | F@1: 23.75 | M@1: 34.77 | V-Loss: 2.4671 | F-Loss: 2.4841 | M-Loss: 1.9545 | GKL: 0.0000
# 📊 Epoch 50/100 | V@1: 19.92 | Top-5: 52.19 | F@1: 19.69 | M@1: 30.39 | V-Loss: 2.4227 | F-Loss: 2.4264 | M-Loss: 1.9032 | GKL: 0.0000
# 📊 Epoch 51/100 | V@1: 24.06 | Top-5: 56.33 | F@1: 22.81 | M@1: 34.06 | V-Loss: 2.3872 | F-Loss: 2.4161 | M-Loss: 1.8905 | GKL: 0.0000
# 📊 Epoch 52/100 | V@1: 23.05 | Top-5: 57.34 | F@1: 22.89 | M@1: 34.69 | V-Loss: 2.5911 | F-Loss: 2.6049 | M-Loss: 2.0236 | GKL: 0.0000
# 📊 Epoch 53/100 | V@1: 19.77 | Top-5: 48.20 | F@1: 18.20 | M@1: 28.59 | V-Loss: 2.4744 | F-Loss: 2.4978 | M-Loss: 1.9526 | GKL: 0.0000
# 📊 Epoch 54/100 | V@1: 27.81 | Top-5: 62.50 | F@1: 28.12 | M@1: 37.03 | V-Loss: 2.4207 | F-Loss: 2.4385 | M-Loss: 1.9203 | GKL: 0.0000
# 📊 Epoch 55/100 | V@1: 24.92 | Top-5: 54.53 | F@1: 25.23 | M@1: 32.73 | V-Loss: 2.4283 | F-Loss: 2.4468 | M-Loss: 1.9267 | GKL: 0.0000
# 📊 Epoch 56/100 | V@1: 35.39 | Top-5: 70.94 | F@1: 34.77 | M@1: 44.77 | V-Loss: 2.2490 | F-Loss: 2.2623 | M-Loss: 1.7825 | GKL: 0.0000
# 📊 Epoch 57/100 | V@1: 32.03 | Top-5: 63.12 | F@1: 31.56 | M@1: 39.77 | V-Loss: 2.3400 | F-Loss: 2.3486 | M-Loss: 1.8798 | GKL: 0.0000
# 📊 Epoch 58/100 | V@1: 31.09 | Top-5: 62.42 | F@1: 29.69 | M@1: 40.31 | V-Loss: 2.3921 | F-Loss: 2.4083 | M-Loss: 1.8893 | GKL: 0.0000
# 📊 Epoch 59/100 | V@1: 17.19 | Top-5: 43.28 | F@1: 16.17 | M@1: 24.45 | V-Loss: 2.2015 | F-Loss: 2.2098 | M-Loss: 1.7725 | GKL: 0.0000
# 📊 Epoch 60/100 | V@1: 16.17 | Top-5: 46.72 | F@1: 15.70 | M@1: 27.11 | V-Loss: 2.3864 | F-Loss: 2.3951 | M-Loss: 1.8896 | GKL: 0.0000
# 📊 Epoch 61/100 | V@1: 23.12 | Top-5: 51.72 | F@1: 22.34 | M@1: 32.89 | V-Loss: 2.4989 | F-Loss: 2.5080 | M-Loss: 1.9714 | GKL: 0.0000
# 📊 Epoch 62/100 | V@1: 25.55 | Top-5: 55.62 | F@1: 25.00 | M@1: 33.91 | V-Loss: 2.3194 | F-Loss: 2.3318 | M-Loss: 1.8530 | GKL: 0.0000
# 📊 Epoch 63/100 | V@1: 35.62 | Top-5: 64.61 | F@1: 34.84 | M@1: 41.95 | V-Loss: 2.3258 | F-Loss: 2.3330 | M-Loss: 1.8553 | GKL: 0.0000
# 📊 Epoch 64/100 | V@1: 21.48 | Top-5: 52.50 | F@1: 21.25 | M@1: 32.03 | V-Loss: 2.5509 | F-Loss: 2.5593 | M-Loss: 2.0206 | GKL: 0.0000
# 📊 Epoch 65/100 | V@1: 20.47 | Top-5: 47.66 | F@1: 20.16 | M@1: 29.53 | V-Loss: 2.2377 | F-Loss: 2.2496 | M-Loss: 1.7891 | GKL: 0.0000
# 📊 Epoch 66/100 | V@1: 35.62 | Top-5: 66.80 | F@1: 35.62 | M@1: 45.08 | V-Loss: 2.2044 | F-Loss: 2.2170 | M-Loss: 1.7702 | GKL: 0.0000
# 📊 Epoch 67/100 | V@1: 20.39 | Top-5: 49.30 | F@1: 20.23 | M@1: 30.00 | V-Loss: 2.2461 | F-Loss: 2.2588 | M-Loss: 1.7948 | GKL: 0.0000
# 📊 Epoch 68/100 | V@1: 29.22 | Top-5: 59.53 | F@1: 29.38 | M@1: 37.97 | V-Loss: 2.2631 | F-Loss: 2.2727 | M-Loss: 1.8005 | GKL: 0.0000
# 📊 Epoch 69/100 | V@1: 39.45 | Top-5: 70.70 | F@1: 38.59 | M@1: 47.34 | V-Loss: 2.1006 | F-Loss: 2.1018 | M-Loss: 1.6738 | GKL: 0.0000
# 📊 Epoch 70/100 | V@1: 42.89 | Top-5: 74.38 | F@1: 42.89 | M@1: 50.70 | V-Loss: 2.1939 | F-Loss: 2.2010 | M-Loss: 1.7448 | GKL: 0.0000
# 📊 Epoch 71/100 | V@1: 24.92 | Top-5: 57.34 | F@1: 25.23 | M@1: 34.14 | V-Loss: 2.3265 | F-Loss: 2.3346 | M-Loss: 1.8556 | GKL: 0.0000
# 📊 Epoch 72/100 | V@1: 42.34 | Top-5: 76.09 | F@1: 41.64 | M@1: 50.62 | V-Loss: 2.2091 | F-Loss: 2.2105 | M-Loss: 1.7545 | GKL: 0.0000
# 📊 Epoch 73/100 | V@1: 32.42 | Top-5: 59.30 | F@1: 31.88 | M@1: 40.31 | V-Loss: 2.0310 | F-Loss: 2.0320 | M-Loss: 1.6105 | GKL: 0.0000
# 📊 Epoch 74/100 | V@1: 40.39 | Top-5: 71.80 | F@1: 40.47 | M@1: 46.56 | V-Loss: 2.1988 | F-Loss: 2.2048 | M-Loss: 1.7492 | GKL: 0.0000
# 📊 Epoch 75/100 | V@1: 32.34 | Top-5: 60.55 | F@1: 31.72 | M@1: 39.14 | V-Loss: 2.1119 | F-Loss: 2.1176 | M-Loss: 1.6925 | GKL: 0.0000
# 📊 Epoch 76/100 | V@1: 33.59 | Top-5: 68.20 | F@1: 32.89 | M@1: 40.78 | V-Loss: 2.4370 | F-Loss: 2.4381 | M-Loss: 1.9409 | GKL: 0.0000
# 📊 Epoch 77/100 | V@1: 36.33 | Top-5: 68.67 | F@1: 35.62 | M@1: 43.28 | V-Loss: 2.0968 | F-Loss: 2.1054 | M-Loss: 1.6741 | GKL: 0.0000
# 📊 Epoch 78/100 | V@1: 34.53 | Top-5: 67.81 | F@1: 34.22 | M@1: 42.03 | V-Loss: 2.2701 | F-Loss: 2.2748 | M-Loss: 1.8143 | GKL: 0.0000
# 📊 Epoch 79/100 | V@1: 26.33 | Top-5: 56.25 | F@1: 26.56 | M@1: 34.22 | V-Loss: 2.2379 | F-Loss: 2.2417 | M-Loss: 1.7977 | GKL: 0.0000
# 📊 Epoch 80/100 | V@1: 42.19 | Top-5: 78.59 | F@1: 41.80 | M@1: 49.69 | V-Loss: 2.3017 | F-Loss: 2.3008 | M-Loss: 1.8270 | GKL: 0.0000
# 📊 Epoch 81/100 | V@1: 47.03 | Top-5: 78.12 | F@1: 47.73 | M@1: 53.28 | V-Loss: 2.1480 | F-Loss: 2.1450 | M-Loss: 1.7199 | GKL: 0.0000
# 📊 Epoch 82/100 | V@1: 29.69 | Top-5: 59.38 | F@1: 29.92 | M@1: 38.28 | V-Loss: 2.1146 | F-Loss: 2.1122 | M-Loss: 1.6852 | GKL: 0.0000
# 📊 Epoch 83/100 | V@1: 34.22 | Top-5: 64.30 | F@1: 34.45 | M@1: 42.58 | V-Loss: 2.0209 | F-Loss: 2.0127 | M-Loss: 1.6091 | GKL: 0.0000
# 📊 Epoch 84/100 | V@1: 35.00 | Top-5: 64.69 | F@1: 34.22 | M@1: 41.88 | V-Loss: 2.1961 | F-Loss: 2.1965 | M-Loss: 1.7721 | GKL: 0.0000
# 📊 Epoch 85/100 | V@1: 40.08 | Top-5: 71.02 | F@1: 40.55 | M@1: 48.12 | V-Loss: 2.0595 | F-Loss: 2.0547 | M-Loss: 1.6420 | GKL: 0.0000
# 📊 Epoch 86/100 | V@1: 39.92 | Top-5: 67.19 | F@1: 39.45 | M@1: 46.25 | V-Loss: 2.0780 | F-Loss: 2.0706 | M-Loss: 1.6641 | GKL: 0.0000
# 📊 Epoch 87/100 | V@1: 43.91 | Top-5: 73.67 | F@1: 44.30 | M@1: 50.23 | V-Loss: 1.9516 | F-Loss: 1.9391 | M-Loss: 1.5592 | GKL: 0.0000
# 📊 Epoch 88/100 | V@1: 31.41 | Top-5: 62.11 | F@1: 31.80 | M@1: 39.06 | V-Loss: 2.1555 | F-Loss: 2.1493 | M-Loss: 1.7169 | GKL: 0.0000
# 📊 Epoch 89/100 | V@1: 36.02 | Top-5: 65.70 | F@1: 36.02 | M@1: 44.69 | V-Loss: 2.0912 | F-Loss: 2.0877 | M-Loss: 1.6548 | GKL: 0.0000
# 📊 Epoch 90/100 | V@1: 36.48 | Top-5: 66.56 | F@1: 36.33 | M@1: 42.89 | V-Loss: 2.2523 | F-Loss: 2.2472 | M-Loss: 1.7847 | GKL: 0.0000
# 📊 Epoch 91/100 | V@1: 32.73 | Top-5: 60.16 | F@1: 32.89 | M@1: 39.61 | V-Loss: 2.0479 | F-Loss: 2.0385 | M-Loss: 1.6413 | GKL: 0.0000
# 📊 Epoch 92/100 | V@1: 39.22 | Top-5: 70.47 | F@1: 39.53 | M@1: 46.80 | V-Loss: 2.0795 | F-Loss: 2.0783 | M-Loss: 1.6650 | GKL: 0.0000
# 📊 Epoch 93/100 | V@1: 38.20 | Top-5: 66.09 | F@1: 38.44 | M@1: 44.53 | V-Loss: 2.0717 | F-Loss: 2.0657 | M-Loss: 1.6472 | GKL: 0.0000
# 📊 Epoch 94/100 | V@1: 34.69 | Top-5: 64.45 | F@1: 34.45 | M@1: 43.83 | V-Loss: 2.2235 | F-Loss: 2.2130 | M-Loss: 1.7593 | GKL: 0.0000
# 📊 Epoch 95/100 | V@1: 39.22 | Top-5: 71.80 | F@1: 40.00 | M@1: 46.64 | V-Loss: 2.2736 | F-Loss: 2.2690 | M-Loss: 1.8049 | GKL: 0.0000
# 📊 Epoch 96/100 | V@1: 36.41 | Top-5: 68.59 | F@1: 36.64 | M@1: 43.36 | V-Loss: 2.3125 | F-Loss: 2.3100 | M-Loss: 1.8534 | GKL: 0.0000
# 📊 Epoch 97/100 | V@1: 43.59 | Top-5: 71.02 | F@1: 44.53 | M@1: 50.39 | V-Loss: 1.8763 | F-Loss: 1.8646 | M-Loss: 1.5001 | GKL: 0.0000
# 📊 Epoch 98/100 | V@1: 37.97 | Top-5: 64.69 | F@1: 38.20 | M@1: 44.38 | V-Loss: 1.9990 | F-Loss: 1.9944 | M-Loss: 1.6098 | GKL: 0.0000
# 📊 Epoch 99/100 | V@1: 45.62 | Top-5: 72.34 | F@1: 45.08 | M@1: 49.69 | V-Loss: 2.0302 | F-Loss: 2.0194 | M-Loss: 1.6290 | GKL: 0.0000
# 📊 Epoch 100/100 | V@1: 36.72 | Top-5: 66.48 | F@1: 36.48 | M@1: 44.45 | V-Loss: 2.1945 | F-Loss: 2.1918 | M-Loss: 1.7515 | GKL: 0.0000
#
# ✅ Task 4 Completed
#    ✈️ Variant Accuracy: 36.72
#    🎯 Top-5 Accuracy: 66.48
#    🏷️ Family Accuracy: 36.48
#    🏭 Manufacturer Accuracy: 44.45
#    🔻 Split Loss: 2.1945
#    🔻 Family Loss: 2.1918
#    🔻 Manufacturer Loss: 1.7515
#
#
# 🚀 Training task_5 | 1668 samples
# 📊 Epoch 1/100 | V@1: 6.43 | Top-5: 25.66 | F@1: 6.19 | M@1: 17.25 | V-Loss: 3.2877 | F-Loss: 3.4550 | M-Loss: 2.6504 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 14.48 | Top-5: 42.07 | F@1: 16.23 | M@1: 22.06 | V-Loss: 2.9587 | F-Loss: 2.9488 | M-Loss: 2.4628 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 13.40 | Top-5: 40.32 | F@1: 13.58 | M@1: 20.49 | V-Loss: 2.8773 | F-Loss: 2.8424 | M-Loss: 2.4056 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 18.45 | Top-5: 46.33 | F@1: 17.07 | M@1: 23.56 | V-Loss: 2.7215 | F-Loss: 2.6922 | M-Loss: 2.2892 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 23.80 | Top-5: 52.70 | F@1: 22.90 | M@1: 26.92 | V-Loss: 2.5996 | F-Loss: 2.5755 | M-Loss: 2.1827 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 24.28 | Top-5: 54.45 | F@1: 24.82 | M@1: 29.39 | V-Loss: 2.6713 | F-Loss: 2.6442 | M-Loss: 2.1810 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 31.85 | Top-5: 65.62 | F@1: 31.37 | M@1: 36.96 | V-Loss: 2.5798 | F-Loss: 2.5703 | M-Loss: 2.1254 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 21.15 | Top-5: 50.60 | F@1: 19.89 | M@1: 28.19 | V-Loss: 2.6657 | F-Loss: 2.6692 | M-Loss: 2.1768 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 24.46 | Top-5: 53.91 | F@1: 23.92 | M@1: 30.77 | V-Loss: 2.6994 | F-Loss: 2.6837 | M-Loss: 2.1882 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 23.14 | Top-5: 53.73 | F@1: 21.88 | M@1: 32.39 | V-Loss: 2.6742 | F-Loss: 2.6660 | M-Loss: 2.1507 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 17.13 | Top-5: 44.89 | F@1: 16.53 | M@1: 24.22 | V-Loss: 2.7787 | F-Loss: 2.7544 | M-Loss: 2.2303 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 26.32 | Top-5: 57.27 | F@1: 25.90 | M@1: 32.81 | V-Loss: 2.5841 | F-Loss: 2.5652 | M-Loss: 2.0892 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 20.91 | Top-5: 50.42 | F@1: 22.48 | M@1: 30.23 | V-Loss: 2.6897 | F-Loss: 2.6586 | M-Loss: 2.1473 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 22.60 | Top-5: 50.90 | F@1: 22.18 | M@1: 29.09 | V-Loss: 2.5425 | F-Loss: 2.5310 | M-Loss: 2.0527 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 28.43 | Top-5: 60.88 | F@1: 26.92 | M@1: 36.48 | V-Loss: 2.7228 | F-Loss: 2.7208 | M-Loss: 2.1971 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 22.54 | Top-5: 50.90 | F@1: 23.20 | M@1: 28.19 | V-Loss: 2.4908 | F-Loss: 2.4789 | M-Loss: 1.9981 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 24.40 | Top-5: 54.45 | F@1: 24.88 | M@1: 32.15 | V-Loss: 2.7389 | F-Loss: 2.7087 | M-Loss: 2.1723 | GKL: 0.0000
# 📊 Epoch 18/100 | V@1: 17.01 | Top-5: 43.21 | F@1: 17.13 | M@1: 24.16 | V-Loss: 2.6912 | F-Loss: 2.6780 | M-Loss: 2.1640 | GKL: 0.0000
# 📊 Epoch 19/100 | V@1: 21.51 | Top-5: 47.54 | F@1: 21.75 | M@1: 28.79 | V-Loss: 2.4932 | F-Loss: 2.4733 | M-Loss: 2.0253 | GKL: 0.0000
# 📊 Epoch 20/100 | V@1: 23.98 | Top-5: 54.33 | F@1: 22.84 | M@1: 31.01 | V-Loss: 2.6790 | F-Loss: 2.6682 | M-Loss: 2.1459 | GKL: 0.0000
# 📊 Epoch 21/100 | V@1: 26.56 | Top-5: 55.95 | F@1: 25.78 | M@1: 33.29 | V-Loss: 2.5049 | F-Loss: 2.4946 | M-Loss: 2.0172 | GKL: 0.0000
# 📊 Epoch 22/100 | V@1: 21.94 | Top-5: 49.76 | F@1: 22.72 | M@1: 28.97 | V-Loss: 2.6243 | F-Loss: 2.5873 | M-Loss: 2.1053 | GKL: 0.0000
# 📊 Epoch 23/100 | V@1: 20.73 | Top-5: 48.92 | F@1: 21.33 | M@1: 28.67 | V-Loss: 2.6257 | F-Loss: 2.5975 | M-Loss: 2.1084 | GKL: 0.0000
# 📊 Epoch 24/100 | V@1: 36.42 | Top-5: 66.59 | F@1: 36.78 | M@1: 43.21 | V-Loss: 2.3178 | F-Loss: 2.2989 | M-Loss: 1.8923 | GKL: 0.0000
# 📊 Epoch 25/100 | V@1: 12.02 | Top-5: 35.70 | F@1: 12.80 | M@1: 18.75 | V-Loss: 2.5618 | F-Loss: 2.5302 | M-Loss: 2.0574 | GKL: 0.0000
# 📊 Epoch 26/100 | V@1: 26.26 | Top-5: 52.94 | F@1: 26.08 | M@1: 32.45 | V-Loss: 2.3538 | F-Loss: 2.3303 | M-Loss: 1.9077 | GKL: 0.0000
# 📊 Epoch 27/100 | V@1: 32.39 | Top-5: 63.04 | F@1: 32.27 | M@1: 38.46 | V-Loss: 2.4826 | F-Loss: 2.4614 | M-Loss: 2.0061 | GKL: 0.0000
# 📊 Epoch 28/100 | V@1: 19.53 | Top-5: 45.97 | F@1: 20.55 | M@1: 26.80 | V-Loss: 2.5535 | F-Loss: 2.5284 | M-Loss: 2.0581 | GKL: 0.0000
# 📊 Epoch 29/100 | V@1: 35.52 | Top-5: 63.40 | F@1: 36.00 | M@1: 42.25 | V-Loss: 2.4010 | F-Loss: 2.3750 | M-Loss: 1.9520 | GKL: 0.0000
# 📊 Epoch 30/100 | V@1: 28.73 | Top-5: 56.07 | F@1: 28.79 | M@1: 33.29 | V-Loss: 2.4593 | F-Loss: 2.4373 | M-Loss: 2.0055 | GKL: 0.0000
# 📊 Epoch 31/100 | V@1: 26.26 | Top-5: 54.45 | F@1: 26.50 | M@1: 32.27 | V-Loss: 2.4231 | F-Loss: 2.3939 | M-Loss: 1.9732 | GKL: 0.0000
# 📊 Epoch 32/100 | V@1: 32.69 | Top-5: 62.74 | F@1: 32.87 | M@1: 38.46 | V-Loss: 2.4723 | F-Loss: 2.4354 | M-Loss: 1.9971 | GKL: 0.0000
# 📊 Epoch 33/100 | V@1: 27.04 | Top-5: 57.81 | F@1: 27.22 | M@1: 34.80 | V-Loss: 2.5077 | F-Loss: 2.4883 | M-Loss: 2.0185 | GKL: 0.0000
# 📊 Epoch 34/100 | V@1: 36.66 | Top-5: 71.33 | F@1: 37.08 | M@1: 42.91 | V-Loss: 2.5732 | F-Loss: 2.5504 | M-Loss: 2.0689 | GKL: 0.0000
# 🛑 Early stopping at epoch 34 due to no improvement in variant loss.
#
# ✅ Task 5 Completed
#    ✈️ Variant Accuracy: 36.66
#    🎯 Top-5 Accuracy: 71.33
#    🏷️ Family Accuracy: 37.08
#    🏭 Manufacturer Accuracy: 42.91
#    🔻 Split Loss: 2.5732
#    🔻 Family Loss: 2.5504
#    🔻 Manufacturer Loss: 2.0689
#
#
# 🚀 Training task_6 | 2001 samples
# 📊 Epoch 1/100 | V@1: 13.18 | Top-5: 38.12 | F@1: 13.91 | M@1: 27.50 | V-Loss: 3.1937 | F-Loss: 3.1977 | M-Loss: 2.3084 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 23.12 | Top-5: 50.52 | F@1: 24.22 | M@1: 30.68 | V-Loss: 2.7318 | F-Loss: 2.7084 | M-Loss: 2.1108 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 33.39 | Top-5: 65.52 | F@1: 33.65 | M@1: 40.57 | V-Loss: 2.7122 | F-Loss: 2.6629 | M-Loss: 2.0872 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 34.48 | Top-5: 63.07 | F@1: 35.42 | M@1: 42.45 | V-Loss: 2.4923 | F-Loss: 2.4292 | M-Loss: 1.9133 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 33.80 | Top-5: 63.49 | F@1: 34.27 | M@1: 41.82 | V-Loss: 2.5771 | F-Loss: 2.5153 | M-Loss: 1.9838 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 28.07 | Top-5: 56.56 | F@1: 28.65 | M@1: 36.41 | V-Loss: 2.6616 | F-Loss: 2.6070 | M-Loss: 2.0415 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 26.88 | Top-5: 52.50 | F@1: 28.23 | M@1: 33.65 | V-Loss: 2.4909 | F-Loss: 2.4330 | M-Loss: 1.9069 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 25.05 | Top-5: 56.25 | F@1: 25.73 | M@1: 34.11 | V-Loss: 2.8040 | F-Loss: 2.7508 | M-Loss: 2.1471 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 23.70 | Top-5: 49.38 | F@1: 23.80 | M@1: 30.47 | V-Loss: 2.6332 | F-Loss: 2.5888 | M-Loss: 2.0302 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 19.32 | Top-5: 46.30 | F@1: 20.47 | M@1: 29.43 | V-Loss: 2.7947 | F-Loss: 2.7305 | M-Loss: 2.1154 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 24.38 | Top-5: 51.04 | F@1: 24.74 | M@1: 32.55 | V-Loss: 2.5829 | F-Loss: 2.5406 | M-Loss: 1.9696 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 28.70 | Top-5: 55.78 | F@1: 29.48 | M@1: 37.86 | V-Loss: 2.6738 | F-Loss: 2.6318 | M-Loss: 2.0416 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 19.27 | Top-5: 44.95 | F@1: 19.69 | M@1: 28.39 | V-Loss: 2.7682 | F-Loss: 2.7061 | M-Loss: 2.0965 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 26.20 | Top-5: 53.75 | F@1: 27.24 | M@1: 34.17 | V-Loss: 2.8017 | F-Loss: 2.7478 | M-Loss: 2.1323 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 23.91 | Top-5: 52.40 | F@1: 25.52 | M@1: 33.28 | V-Loss: 2.7432 | F-Loss: 2.6904 | M-Loss: 2.0699 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 26.30 | Top-5: 55.00 | F@1: 27.08 | M@1: 33.96 | V-Loss: 2.7536 | F-Loss: 2.7006 | M-Loss: 2.1100 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 30.21 | Top-5: 57.03 | F@1: 30.36 | M@1: 37.92 | V-Loss: 2.5806 | F-Loss: 2.5267 | M-Loss: 1.9683 | GKL: 0.0000
# 🛑 Early stopping at epoch 17 due to no improvement in variant loss.
#
# ✅ Task 6 Completed
#    ✈️ Variant Accuracy: 30.21
#    🎯 Top-5 Accuracy: 57.03
#    🏷️ Family Accuracy: 30.36
#    🏭 Manufacturer Accuracy: 37.92
#    🔻 Split Loss: 2.5806
#    🔻 Family Loss: 2.5267
#    🔻 Manufacturer Loss: 1.9683
#
#
# 🚀 Training task_7 | 2332 samples
# 📊 Epoch 1/100 | V@1: 16.88 | Top-5: 42.45 | F@1: 20.79 | M@1: 29.56 | V-Loss: 3.1550 | F-Loss: 2.9391 | M-Loss: 2.3804 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 16.49 | Top-5: 38.19 | F@1: 18.49 | M@1: 23.44 | V-Loss: 2.8395 | F-Loss: 2.7226 | M-Loss: 2.2359 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 23.00 | Top-5: 48.96 | F@1: 25.56 | M@1: 31.21 | V-Loss: 2.8203 | F-Loss: 2.6938 | M-Loss: 2.2152 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 24.18 | Top-5: 51.35 | F@1: 27.69 | M@1: 34.29 | V-Loss: 2.7426 | F-Loss: 2.6162 | M-Loss: 2.1463 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 27.00 | Top-5: 52.13 | F@1: 28.95 | M@1: 34.07 | V-Loss: 2.6104 | F-Loss: 2.5062 | M-Loss: 2.0568 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 17.88 | Top-5: 41.32 | F@1: 20.01 | M@1: 26.82 | V-Loss: 2.7012 | F-Loss: 2.5962 | M-Loss: 2.1165 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 29.34 | Top-5: 56.81 | F@1: 31.94 | M@1: 37.28 | V-Loss: 2.6351 | F-Loss: 2.5401 | M-Loss: 2.0725 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 25.82 | Top-5: 52.82 | F@1: 27.17 | M@1: 35.11 | V-Loss: 2.7026 | F-Loss: 2.6219 | M-Loss: 2.1214 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 29.17 | Top-5: 54.12 | F@1: 30.69 | M@1: 36.98 | V-Loss: 2.5900 | F-Loss: 2.5070 | M-Loss: 2.0315 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 26.09 | Top-5: 50.00 | F@1: 26.22 | M@1: 33.64 | V-Loss: 2.5842 | F-Loss: 2.5191 | M-Loss: 2.0087 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 24.13 | Top-5: 46.92 | F@1: 25.35 | M@1: 32.42 | V-Loss: 2.6771 | F-Loss: 2.6025 | M-Loss: 2.0834 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 27.69 | Top-5: 55.03 | F@1: 29.21 | M@1: 36.89 | V-Loss: 2.6459 | F-Loss: 2.5663 | M-Loss: 2.0524 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 19.49 | Top-5: 43.27 | F@1: 20.88 | M@1: 28.21 | V-Loss: 2.7452 | F-Loss: 2.6716 | M-Loss: 2.1251 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 32.38 | Top-5: 59.24 | F@1: 32.99 | M@1: 41.41 | V-Loss: 2.6997 | F-Loss: 2.6223 | M-Loss: 2.0793 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 28.73 | Top-5: 57.16 | F@1: 31.25 | M@1: 38.06 | V-Loss: 2.6976 | F-Loss: 2.6131 | M-Loss: 2.0952 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 25.56 | Top-5: 51.56 | F@1: 27.60 | M@1: 34.07 | V-Loss: 2.7186 | F-Loss: 2.6319 | M-Loss: 2.1080 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 31.51 | Top-5: 59.77 | F@1: 33.42 | M@1: 40.67 | V-Loss: 2.7446 | F-Loss: 2.6531 | M-Loss: 2.1237 | GKL: 0.0000
# 📊 Epoch 18/100 | V@1: 21.22 | Top-5: 46.66 | F@1: 22.87 | M@1: 29.95 | V-Loss: 2.8078 | F-Loss: 2.7103 | M-Loss: 2.1591 | GKL: 0.0000
# 📊 Epoch 19/100 | V@1: 33.29 | Top-5: 59.11 | F@1: 34.72 | M@1: 40.62 | V-Loss: 2.6174 | F-Loss: 2.5326 | M-Loss: 2.0291 | GKL: 0.0000
# 📊 Epoch 20/100 | V@1: 31.68 | Top-5: 58.55 | F@1: 33.03 | M@1: 39.63 | V-Loss: 2.6321 | F-Loss: 2.5538 | M-Loss: 2.0638 | GKL: 0.0000
# 🛑 Early stopping at epoch 20 due to no improvement in variant loss.
#
# ✅ Task 7 Completed
#    ✈️ Variant Accuracy: 31.68
#    🎯 Top-5 Accuracy: 58.55
#    🏷️ Family Accuracy: 33.03
#    🏭 Manufacturer Accuracy: 39.63
#    🔻 Split Loss: 2.6321
#    🔻 Family Loss: 2.5538
#    🔻 Manufacturer Loss: 2.0638
#
#
# 🚀 Training task_8 | 2665 samples
# 📊 Epoch 1/100 | V@1: 18.52 | Top-5: 41.95 | F@1: 23.20 | M@1: 33.83 | V-Loss: 3.2309 | F-Loss: 3.0090 | M-Loss: 2.1778 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 20.90 | Top-5: 43.48 | F@1: 24.18 | M@1: 30.43 | V-Loss: 2.8660 | F-Loss: 2.7142 | M-Loss: 2.1108 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 27.46 | Top-5: 51.76 | F@1: 30.51 | M@1: 35.47 | V-Loss: 2.7138 | F-Loss: 2.5735 | M-Loss: 2.0275 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 35.43 | Top-5: 60.47 | F@1: 38.28 | M@1: 44.34 | V-Loss: 2.5602 | F-Loss: 2.4282 | M-Loss: 1.9210 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 33.32 | Top-5: 58.52 | F@1: 36.60 | M@1: 42.54 | V-Loss: 2.6399 | F-Loss: 2.5208 | M-Loss: 1.9790 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 38.63 | Top-5: 65.90 | F@1: 41.95 | M@1: 47.93 | V-Loss: 2.5724 | F-Loss: 2.4600 | M-Loss: 1.9354 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 26.33 | Top-5: 49.26 | F@1: 27.70 | M@1: 34.22 | V-Loss: 2.6628 | F-Loss: 2.5506 | M-Loss: 2.0073 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 28.28 | Top-5: 54.02 | F@1: 29.96 | M@1: 37.23 | V-Loss: 2.7208 | F-Loss: 2.6216 | M-Loss: 2.0607 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 36.99 | Top-5: 66.52 | F@1: 38.16 | M@1: 44.96 | V-Loss: 2.7590 | F-Loss: 2.6706 | M-Loss: 2.0820 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 22.73 | Top-5: 44.26 | F@1: 24.26 | M@1: 29.53 | V-Loss: 2.5720 | F-Loss: 2.4761 | M-Loss: 1.9452 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 25.59 | Top-5: 48.63 | F@1: 26.41 | M@1: 34.10 | V-Loss: 2.6734 | F-Loss: 2.5706 | M-Loss: 1.9998 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 29.49 | Top-5: 53.55 | F@1: 31.52 | M@1: 37.70 | V-Loss: 2.6157 | F-Loss: 2.5133 | M-Loss: 1.9536 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 31.33 | Top-5: 60.08 | F@1: 34.18 | M@1: 40.62 | V-Loss: 2.7290 | F-Loss: 2.6277 | M-Loss: 2.0564 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 28.16 | Top-5: 52.46 | F@1: 29.06 | M@1: 35.66 | V-Loss: 2.7965 | F-Loss: 2.7012 | M-Loss: 2.1078 | GKL: 0.0000
# 🛑 Early stopping at epoch 14 due to no improvement in variant loss.
#
# ✅ Task 8 Completed
#    ✈️ Variant Accuracy: 28.16
#    🎯 Top-5 Accuracy: 52.46
#    🏷️ Family Accuracy: 29.06
#    🏭 Manufacturer Accuracy: 35.66
#    🔻 Split Loss: 2.7965
#    🔻 Family Loss: 2.7012
#    🔻 Manufacturer Loss: 2.1078
#
#
# 🚀 Training task_9 | 2999 samples
# 📊 Epoch 1/100 | V@1: 13.55 | Top-5: 35.53 | F@1: 14.47 | M@1: 20.96 | V-Loss: 3.4442 | F-Loss: 3.3263 | M-Loss: 2.6987 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 29.96 | Top-5: 57.44 | F@1: 32.64 | M@1: 33.63 | V-Loss: 2.9236 | F-Loss: 2.7981 | M-Loss: 2.3454 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 27.65 | Top-5: 52.07 | F@1: 30.16 | M@1: 32.51 | V-Loss: 2.8079 | F-Loss: 2.6808 | M-Loss: 2.2267 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 23.00 | Top-5: 46.03 | F@1: 24.42 | M@1: 30.26 | V-Loss: 2.9716 | F-Loss: 2.8442 | M-Loss: 2.2943 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 15.25 | Top-5: 34.71 | F@1: 16.03 | M@1: 23.81 | V-Loss: 2.9402 | F-Loss: 2.8240 | M-Loss: 2.2727 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 29.42 | Top-5: 51.43 | F@1: 30.94 | M@1: 37.06 | V-Loss: 2.6047 | F-Loss: 2.5038 | M-Loss: 2.0066 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 33.73 | Top-5: 58.90 | F@1: 35.12 | M@1: 41.07 | V-Loss: 2.7558 | F-Loss: 2.6611 | M-Loss: 2.1231 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 27.24 | Top-5: 52.85 | F@1: 27.51 | M@1: 34.95 | V-Loss: 2.8914 | F-Loss: 2.7977 | M-Loss: 2.2000 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 23.91 | Top-5: 47.69 | F@1: 25.34 | M@1: 33.32 | V-Loss: 2.8507 | F-Loss: 2.7503 | M-Loss: 2.1594 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 31.73 | Top-5: 57.30 | F@1: 32.03 | M@1: 40.56 | V-Loss: 2.8049 | F-Loss: 2.7201 | M-Loss: 2.1321 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 31.18 | Top-5: 57.57 | F@1: 32.91 | M@1: 39.06 | V-Loss: 2.8346 | F-Loss: 2.7437 | M-Loss: 2.1389 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 22.83 | Top-5: 44.77 | F@1: 23.40 | M@1: 30.54 | V-Loss: 2.8715 | F-Loss: 2.7794 | M-Loss: 2.1744 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 26.29 | Top-5: 49.05 | F@1: 27.41 | M@1: 34.21 | V-Loss: 2.7545 | F-Loss: 2.6587 | M-Loss: 2.0834 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 33.08 | Top-5: 62.13 | F@1: 34.65 | M@1: 43.00 | V-Loss: 2.7384 | F-Loss: 2.6550 | M-Loss: 2.0732 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 33.05 | Top-5: 57.51 | F@1: 33.70 | M@1: 41.07 | V-Loss: 2.6756 | F-Loss: 2.5874 | M-Loss: 2.0386 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 26.60 | Top-5: 50.88 | F@1: 28.12 | M@1: 35.09 | V-Loss: 2.6641 | F-Loss: 2.5889 | M-Loss: 2.0293 | GKL: 0.0000
# 🛑 Early stopping at epoch 16 due to no improvement in variant loss.
#
# ✅ Task 9 Completed
#    ✈️ Variant Accuracy: 26.60
#    🎯 Top-5 Accuracy: 50.88
#    🏷️ Family Accuracy: 28.12
#    🏭 Manufacturer Accuracy: 35.09
#    🔻 Split Loss: 2.6641
#    🔻 Family Loss: 2.5889
#    🔻 Manufacturer Loss: 2.0293
#
#
# 🚀 Training task_10 | 3334 samples
# 📊 Epoch 1/100 | V@1: 8.62 | Top-5: 24.46 | F@1: 11.96 | M@1: 18.57 | V-Loss: 3.6094 | F-Loss: 3.3930 | M-Loss: 2.7657 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 19.14 | Top-5: 41.20 | F@1: 22.57 | M@1: 26.50 | V-Loss: 2.9728 | F-Loss: 2.7726 | M-Loss: 2.3141 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 24.31 | Top-5: 46.45 | F@1: 26.56 | M@1: 31.91 | V-Loss: 2.9131 | F-Loss: 2.7093 | M-Loss: 2.2322 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 25.57 | Top-5: 50.93 | F@1: 28.31 | M@1: 33.65 | V-Loss: 2.9826 | F-Loss: 2.7909 | M-Loss: 2.2485 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 25.72 | Top-5: 48.02 | F@1: 29.24 | M@1: 34.47 | V-Loss: 2.7949 | F-Loss: 2.6079 | M-Loss: 2.1074 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 30.23 | Top-5: 54.54 | F@1: 33.29 | M@1: 40.17 | V-Loss: 2.7789 | F-Loss: 2.6078 | M-Loss: 2.0953 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 25.39 | Top-5: 47.30 | F@1: 27.70 | M@1: 33.95 | V-Loss: 2.7737 | F-Loss: 2.6152 | M-Loss: 2.0875 | GKL: 0.0000
# ...
# 📊 Epoch 33/100 | V@1: 37.07 | Top-5: 56.53 | F@1: 39.54 | M@1: 46.35 | V-Loss: 2.4983 | F-Loss: 2.3148 | M-Loss: 1.8238 | GKL: 0.0000
# 📊 Epoch 34/100 | V@1: 41.38 | Top-5: 62.75 | F@1: 44.53 | M@1: 49.34 | V-Loss: 2.5652 | F-Loss: 2.3800 | M-Loss: 1.8969 | GKL: 0.0000
# 📊 Epoch 35/100 | V@1: 42.84 | Top-5: 63.28 | F@1: 46.02 | M@1: 51.01 | V-Loss: 2.3954 | F-Loss: 2.2115 | M-Loss: 1.7676 | GKL: 0.0000
# 📊 Epoch 36/100 | V@1: 42.99 | Top-5: 62.88 | F@1: 45.99 | M@1: 51.03 | V-Loss: 2.4244 | F-Loss: 2.2465 | M-Loss: 1.7875 | GKL: 0.0000
# 📊 Epoch 37/100 | V@1: 38.43 | Top-5: 55.54 | F@1: 40.93 | M@1: 44.86 | V-Loss: 2.4063 | F-Loss: 2.2318 | M-Loss: 1.7801 | GKL: 0.0000
# 📊 Epoch 38/100 | V@1: 42.24 | Top-5: 61.59 | F@1: 45.11 | M@1: 49.77 | V-Loss: 2.4595 | F-Loss: 2.2832 | M-Loss: 1.8191 | GKL: 0.0000
# 📊 Epoch 39/100 | V@1: 50.28 | Top-5: 70.39 | F@1: 53.35 | M@1: 57.16 | V-Loss: 2.2354 | F-Loss: 2.0686 | M-Loss: 1.6582 | GKL: 0.0000
# 📊 Epoch 40/100 | V@1: 39.01 | Top-5: 60.13 | F@1: 42.11 | M@1: 46.75 | V-Loss: 2.5404 | F-Loss: 2.3503 | M-Loss: 1.8785 | GKL: 0.0000
# 📊 Epoch 41/100 | V@1: 42.14 | Top-5: 60.51 | F@1: 45.26 | M@1: 48.74 | V-Loss: 2.4775 | F-Loss: 2.2943 | M-Loss: 1.8341 | GKL: 0.0000
# 📊 Epoch 42/100 | V@1: 44.35 | Top-5: 64.39 | F@1: 47.38 | M@1: 51.94 | V-Loss: 2.4326 | F-Loss: 2.2499 | M-Loss: 1.7964 | GKL: 0.0000
# 📊 Epoch 43/100 | V@1: 50.10 | Top-5: 69.76 | F@1: 51.86 | M@1: 57.81 | V-Loss: 2.4258 | F-Loss: 2.2451 | M-Loss: 1.7872 | GKL: 0.0000
# 📊 Epoch 44/100 | V@1: 47.28 | Top-5: 64.49 | F@1: 50.15 | M@1: 54.26 | V-Loss: 2.3059 | F-Loss: 2.1257 | M-Loss: 1.6942 | GKL: 0.0000
# 📊 Epoch 45/100 | V@1: 41.43 | Top-5: 59.17 | F@1: 43.52 | M@1: 48.49 | V-Loss: 2.3774 | F-Loss: 2.2076 | M-Loss: 1.7597 | GKL: 0.0000
# 📊 Epoch 46/100 | V@1: 46.65 | Top-5: 64.01 | F@1: 48.69 | M@1: 52.87 | V-Loss: 2.2955 | F-Loss: 2.1326 | M-Loss: 1.7069 | GKL: 0.0000
# 📊 Epoch 47/100 | V@1: 37.35 | Top-5: 57.66 | F@1: 40.57 | M@1: 45.99 | V-Loss: 2.5122 | F-Loss: 2.3327 | M-Loss: 1.8602 | GKL: 0.0000
# 📊 Epoch 48/100 | V@1: 37.88 | Top-5: 56.15 | F@1: 40.42 | M@1: 45.31 | V-Loss: 2.3762 | F-Loss: 2.2013 | M-Loss: 1.7616 | GKL: 0.0000
# 📊 Epoch 49/100 | V@1: 29.39 | Top-5: 47.08 | F@1: 31.83 | M@1: 36.97 | V-Loss: 2.3335 | F-Loss: 2.1724 | M-Loss: 1.7494 | GKL: 0.0000
# 🛑 Early stopping at epoch 49 due to no improvement in variant loss.
#
# ✅ Task 12 Completed
#    ✈️ Variant Accuracy: 29.39
#    🎯 Top-5 Accuracy: 47.08
#    🏷️ Family Accuracy: 31.83
#    🏭 Manufacturer Accuracy: 36.97
#    🔻 Split Loss: 2.3335
#    🔻 Family Loss: 2.1724
#    🔻 Manufacturer Loss: 1.7494
#
#
# 🚀 Training task_13 | 4334 samples
# 📊 Epoch 1/100 | V@1: 17.02 | Top-5: 39.20 | F@1: 36.10 | M@1: 45.62 | V-Loss: 3.5755 | F-Loss: 2.7569 | M-Loss: 2.0116 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 22.82 | Top-5: 41.76 | F@1: 29.88 | M@1: 36.51 | V-Loss: 2.9458 | F-Loss: 2.4983 | M-Loss: 1.9350 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 29.47 | Top-5: 49.83 | F@1: 37.00 | M@1: 42.52 | V-Loss: 2.8166 | F-Loss: 2.4105 | M-Loss: 1.8807 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 39.65 | Top-5: 59.64 | F@1: 46.64 | M@1: 51.78 | V-Loss: 2.7569 | F-Loss: 2.3668 | M-Loss: 1.8519 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 26.94 | Top-5: 46.66 | F@1: 32.67 | M@1: 38.64 | V-Loss: 2.7888 | F-Loss: 2.4207 | M-Loss: 1.8945 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 30.78 | Top-5: 48.46 | F@1: 35.39 | M@1: 40.70 | V-Loss: 2.6443 | F-Loss: 2.3028 | M-Loss: 1.8062 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 41.50 | Top-5: 62.67 | F@1: 46.95 | M@1: 52.15 | V-Loss: 2.6388 | F-Loss: 2.3146 | M-Loss: 1.8185 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 35.49 | Top-5: 55.82 | F@1: 40.18 | M@1: 45.76 | V-Loss: 2.6692 | F-Loss: 2.3621 | M-Loss: 1.8606 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 45.24 | Top-5: 63.83 | F@1: 50.43 | M@1: 54.85 | V-Loss: 2.3845 | F-Loss: 2.0986 | M-Loss: 1.6466 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 35.01 | Top-5: 52.30 | F@1: 39.56 | M@1: 44.48 | V-Loss: 2.4786 | F-Loss: 2.2036 | M-Loss: 1.7452 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 34.54 | Top-5: 54.69 | F@1: 38.49 | M@1: 43.80 | V-Loss: 2.7794 | F-Loss: 2.4935 | M-Loss: 1.9553 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 36.15 | Top-5: 57.60 | F@1: 41.62 | M@1: 46.88 | V-Loss: 2.7117 | F-Loss: 2.4340 | M-Loss: 1.9003 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 48.96 | Top-5: 70.53 | F@1: 54.76 | M@1: 59.04 | V-Loss: 2.4906 | F-Loss: 2.2307 | M-Loss: 1.7571 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 31.49 | Top-5: 51.96 | F@1: 35.58 | M@1: 40.86 | V-Loss: 2.7073 | F-Loss: 2.4433 | M-Loss: 1.9222 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 38.75 | Top-5: 60.96 | F@1: 43.44 | M@1: 49.01 | V-Loss: 2.6685 | F-Loss: 2.4163 | M-Loss: 1.8964 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 45.76 | Top-5: 67.16 | F@1: 50.50 | M@1: 54.71 | V-Loss: 2.5919 | F-Loss: 2.3335 | M-Loss: 1.8353 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 31.91 | Top-5: 50.73 | F@1: 36.48 | M@1: 42.00 | V-Loss: 2.5568 | F-Loss: 2.2925 | M-Loss: 1.7942 | GKL: 0.0000
# 📊 Epoch 18/100 | V@1: 51.82 | Top-5: 74.27 | F@1: 57.22 | M@1: 61.46 | V-Loss: 2.4565 | F-Loss: 2.1999 | M-Loss: 1.7413 | GKL: 0.0000
# 📊 Epoch 19/100 | V@1: 39.49 | Top-5: 60.11 | F@1: 43.51 | M@1: 48.82 | V-Loss: 2.6304 | F-Loss: 2.3720 | M-Loss: 1.8638 | GKL: 0.0000
# 🛑 Early stopping at epoch 19 due to no improvement in variant loss.
#
# ✅ Task 13 Completed
#    ✈️ Variant Accuracy: 39.49
#    🎯 Top-5 Accuracy: 60.11
#    🏷️ Family Accuracy: 43.51
#    🏭 Manufacturer Accuracy: 48.82
#    🔻 Split Loss: 2.6304
#    🔻 Family Loss: 2.3720
#    🔻 Manufacturer Loss: 1.8638
#
#
# 🚀 Training task_14 | 4668 samples
# 📊 Epoch 1/100 | V@1: 18.64 | Top-5: 37.11 | F@1: 26.95 | M@1: 34.20 | V-Loss: 3.4521 | F-Loss: 2.9830 | M-Loss: 2.3162 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 35.05 | Top-5: 56.45 | F@1: 42.10 | M@1: 48.16 | V-Loss: 2.8935 | F-Loss: 2.5615 | M-Loss: 1.9936 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 36.59 | Top-5: 55.92 | F@1: 42.10 | M@1: 47.01 | V-Loss: 2.7436 | F-Loss: 2.4209 | M-Loss: 1.9022 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 41.88 | Top-5: 59.55 | F@1: 48.29 | M@1: 53.02 | V-Loss: 2.5386 | F-Loss: 2.2190 | M-Loss: 1.7463 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 42.47 | Top-5: 60.85 | F@1: 48.37 | M@1: 52.56 | V-Loss: 2.4594 | F-Loss: 2.1680 | M-Loss: 1.7099 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 28.28 | Top-5: 45.31 | F@1: 31.16 | M@1: 36.85 | V-Loss: 2.6102 | F-Loss: 2.3315 | M-Loss: 1.8459 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 36.07 | Top-5: 53.30 | F@1: 40.36 | M@1: 45.12 | V-Loss: 2.5469 | F-Loss: 2.2833 | M-Loss: 1.8007 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 29.73 | Top-5: 49.39 | F@1: 34.05 | M@1: 39.87 | V-Loss: 2.8246 | F-Loss: 2.5496 | M-Loss: 1.9951 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 34.14 | Top-5: 53.32 | F@1: 38.37 | M@1: 44.31 | V-Loss: 2.6108 | F-Loss: 2.3552 | M-Loss: 1.8460 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 48.22 | Top-5: 67.93 | F@1: 52.67 | M@1: 56.66 | V-Loss: 2.5239 | F-Loss: 2.2696 | M-Loss: 1.8012 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 29.90 | Top-5: 48.74 | F@1: 33.36 | M@1: 39.39 | V-Loss: 2.6993 | F-Loss: 2.4449 | M-Loss: 1.9135 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 40.15 | Top-5: 60.37 | F@1: 44.49 | M@1: 50.52 | V-Loss: 2.6979 | F-Loss: 2.4495 | M-Loss: 1.9140 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 35.00 | Top-5: 55.38 | F@1: 38.59 | M@1: 44.40 | V-Loss: 2.6851 | F-Loss: 2.4497 | M-Loss: 1.9137 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 41.02 | Top-5: 60.57 | F@1: 44.42 | M@1: 49.24 | V-Loss: 2.7031 | F-Loss: 2.4662 | M-Loss: 1.9250 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 42.30 | Top-5: 60.29 | F@1: 45.68 | M@1: 50.67 | V-Loss: 2.5878 | F-Loss: 2.3526 | M-Loss: 1.8316 | GKL: 0.0000
# 🛑 Early stopping at epoch 15 due to no improvement in variant loss.
#
# ✅ Task 14 Completed
#    ✈️ Variant Accuracy: 42.30
#    🎯 Top-5 Accuracy: 60.29
#    🏷️ Family Accuracy: 45.68
#    🏭 Manufacturer Accuracy: 50.67
#    🔻 Split Loss: 2.5878
#    🔻 Family Loss: 2.3526
#    🔻 Manufacturer Loss: 1.8316
#
#
# 🚀 Training task_15 | 5001 samples
# 📊 Epoch 1/100 | V@1: 11.82 | Top-5: 33.77 | F@1: 22.24 | M@1: 36.84 | V-Loss: 3.6348 | F-Loss: 3.1640 | M-Loss: 2.1767 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 32.79 | Top-5: 57.13 | F@1: 41.83 | M@1: 49.56 | V-Loss: 2.9475 | F-Loss: 2.5845 | M-Loss: 1.9644 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 36.68 | Top-5: 58.37 | F@1: 45.91 | M@1: 52.20 | V-Loss: 2.6990 | F-Loss: 2.3311 | M-Loss: 1.7762 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 38.14 | Top-5: 59.11 | F@1: 45.47 | M@1: 51.16 | V-Loss: 2.8044 | F-Loss: 2.4787 | M-Loss: 1.9059 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 32.29 | Top-5: 50.22 | F@1: 37.66 | M@1: 43.79 | V-Loss: 2.7188 | F-Loss: 2.4246 | M-Loss: 1.8730 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 34.84 | Top-5: 53.81 | F@1: 39.48 | M@1: 45.61 | V-Loss: 2.6630 | F-Loss: 2.3898 | M-Loss: 1.8373 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 41.43 | Top-5: 61.20 | F@1: 46.57 | M@1: 51.72 | V-Loss: 2.6974 | F-Loss: 2.4419 | M-Loss: 1.8938 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 40.00 | Top-5: 56.17 | F@1: 43.79 | M@1: 49.64 | V-Loss: 2.3336 | F-Loss: 2.0960 | M-Loss: 1.6207 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 36.16 | Top-5: 56.37 | F@1: 39.78 | M@1: 46.29 | V-Loss: 2.7626 | F-Loss: 2.5219 | M-Loss: 1.9396 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 35.02 | Top-5: 53.51 | F@1: 39.12 | M@1: 45.91 | V-Loss: 2.6632 | F-Loss: 2.4310 | M-Loss: 1.8674 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 28.08 | Top-5: 44.63 | F@1: 30.39 | M@1: 36.58 | V-Loss: 2.6573 | F-Loss: 2.4407 | M-Loss: 1.8768 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 39.34 | Top-5: 56.81 | F@1: 42.65 | M@1: 49.38 | V-Loss: 2.6204 | F-Loss: 2.4017 | M-Loss: 1.8423 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 45.97 | Top-5: 68.03 | F@1: 49.60 | M@1: 56.33 | V-Loss: 2.6984 | F-Loss: 2.4898 | M-Loss: 1.9153 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 31.83 | Top-5: 50.62 | F@1: 34.72 | M@1: 41.55 | V-Loss: 2.8191 | F-Loss: 2.5971 | M-Loss: 1.9958 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 37.78 | Top-5: 56.67 | F@1: 40.52 | M@1: 46.83 | V-Loss: 2.6610 | F-Loss: 2.4452 | M-Loss: 1.8840 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 33.95 | Top-5: 52.28 | F@1: 37.20 | M@1: 43.07 | V-Loss: 2.5650 | F-Loss: 2.3589 | M-Loss: 1.8258 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 41.39 | Top-5: 61.84 | F@1: 45.59 | M@1: 51.84 | V-Loss: 2.6279 | F-Loss: 2.4145 | M-Loss: 1.8545 | GKL: 0.0000
# 📊 Epoch 18/100 | V@1: 46.88 | Top-5: 67.65 | F@1: 51.08 | M@1: 56.33 | V-Loss: 2.6689 | F-Loss: 2.4515 | M-Loss: 1.8905 | GKL: 0.0000
# 🛑 Early stopping at epoch 18 due to no improvement in variant loss.
#
# ✅ Task 15 Completed
#    ✈️ Variant Accuracy: 46.88
#    🎯 Top-5 Accuracy: 67.65
#    🏷️ Family Accuracy: 51.08
#    🏭 Manufacturer Accuracy: 56.33
#    🔻 Split Loss: 2.6689
#    🔻 Family Loss: 2.4515
#    🔻 Manufacturer Loss: 1.8905
#
#
# 🚀 Training task_16 | 5333 samples
# 📊 Epoch 1/100 | V@1: 18.52 | Top-5: 40.76 | F@1: 32.15 | M@1: 36.91 | V-Loss: 3.3997 | F-Loss: 2.7773 | M-Loss: 2.2444 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 26.87 | Top-5: 46.67 | F@1: 33.19 | M@1: 38.62 | V-Loss: 2.9338 | F-Loss: 2.5824 | M-Loss: 2.0578 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 32.83 | Top-5: 53.14 | F@1: 39.29 | M@1: 45.46 | V-Loss: 2.7978 | F-Loss: 2.4707 | M-Loss: 1.9639 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 35.69 | Top-5: 55.03 | F@1: 41.23 | M@1: 46.21 | V-Loss: 2.6960 | F-Loss: 2.3806 | M-Loss: 1.9018 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 31.33 | Top-5: 50.50 | F@1: 35.79 | M@1: 41.69 | V-Loss: 2.7890 | F-Loss: 2.4915 | M-Loss: 1.9826 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 40.78 | Top-5: 59.68 | F@1: 45.31 | M@1: 50.67 | V-Loss: 2.6427 | F-Loss: 2.3566 | M-Loss: 1.8804 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 45.33 | Top-5: 64.18 | F@1: 49.49 | M@1: 54.12 | V-Loss: 2.6069 | F-Loss: 2.3438 | M-Loss: 1.8668 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 45.01 | Top-5: 65.95 | F@1: 49.20 | M@1: 54.92 | V-Loss: 2.7167 | F-Loss: 2.4598 | M-Loss: 1.9455 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 33.21 | Top-5: 49.33 | F@1: 36.81 | M@1: 41.62 | V-Loss: 2.4040 | F-Loss: 2.1821 | M-Loss: 1.7356 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 36.01 | Top-5: 53.47 | F@1: 38.30 | M@1: 43.73 | V-Loss: 2.6294 | F-Loss: 2.4032 | M-Loss: 1.8895 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 46.15 | Top-5: 63.78 | F@1: 49.58 | M@1: 54.86 | V-Loss: 2.5255 | F-Loss: 2.3053 | M-Loss: 1.8195 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 36.78 | Top-5: 57.15 | F@1: 39.96 | M@1: 45.71 | V-Loss: 2.6011 | F-Loss: 2.3802 | M-Loss: 1.8776 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 22.07 | Top-5: 40.19 | F@1: 24.83 | M@1: 31.38 | V-Loss: 2.8509 | F-Loss: 2.6139 | M-Loss: 2.0503 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 36.81 | Top-5: 55.62 | F@1: 40.07 | M@1: 45.87 | V-Loss: 2.7271 | F-Loss: 2.5013 | M-Loss: 1.9568 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 37.16 | Top-5: 55.32 | F@1: 40.40 | M@1: 45.85 | V-Loss: 2.6073 | F-Loss: 2.3838 | M-Loss: 1.8723 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 38.47 | Top-5: 56.46 | F@1: 41.14 | M@1: 46.55 | V-Loss: 2.5573 | F-Loss: 2.3479 | M-Loss: 1.8435 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 36.57 | Top-5: 55.64 | F@1: 39.63 | M@1: 44.72 | V-Loss: 2.6799 | F-Loss: 2.4635 | M-Loss: 1.9427 | GKL: 0.0000
# 📊 Epoch 18/100 | V@1: 42.44 | Top-5: 61.81 | F@1: 45.16 | M@1: 51.12 | V-Loss: 2.6465 | F-Loss: 2.4325 | M-Loss: 1.9015 | GKL: 0.0000
# 📊 Epoch 19/100 | V@1: 41.60 | Top-5: 57.76 | F@1: 45.03 | M@1: 49.92 | V-Loss: 2.4053 | F-Loss: 2.1968 | M-Loss: 1.7354 | GKL: 0.0000
# 🛑 Early stopping at epoch 19 due to no improvement in variant loss.
#
# ✅ Task 16 Completed
#    ✈️ Variant Accuracy: 41.60
#    🎯 Top-5 Accuracy: 57.76
#    🏷️ Family Accuracy: 45.03
#    🏭 Manufacturer Accuracy: 49.92
#    🔻 Split Loss: 2.4053
#    🔻 Family Loss: 2.1968
#    🔻 Manufacturer Loss: 1.7354
#
#
# 🚀 Training task_17 | 5667 samples
# 📊 Epoch 1/100 | V@1: 19.07 | Top-5: 39.06 | F@1: 24.47 | M@1: 41.80 | V-Loss: 3.5884 | F-Loss: 3.2744 | M-Loss: 2.0972 | GKL: 0.0000
# 📊 Epoch 2/100 | V@1: 40.45 | Top-5: 61.75 | F@1: 46.13 | M@1: 53.89 | V-Loss: 2.8952 | F-Loss: 2.6116 | M-Loss: 1.9230 | GKL: 0.0000
# 📊 Epoch 3/100 | V@1: 32.79 | Top-5: 49.06 | F@1: 37.50 | M@1: 44.25 | V-Loss: 2.7155 | F-Loss: 2.4310 | M-Loss: 1.8172 | GKL: 0.0000
# 📊 Epoch 4/100 | V@1: 36.33 | Top-5: 54.30 | F@1: 40.38 | M@1: 46.25 | V-Loss: 2.6781 | F-Loss: 2.4016 | M-Loss: 1.8194 | GKL: 0.0000
# 📊 Epoch 5/100 | V@1: 36.93 | Top-5: 52.34 | F@1: 40.77 | M@1: 46.72 | V-Loss: 2.5877 | F-Loss: 2.3194 | M-Loss: 1.7685 | GKL: 0.0000
# 📊 Epoch 6/100 | V@1: 33.49 | Top-5: 49.56 | F@1: 37.13 | M@1: 43.04 | V-Loss: 2.6262 | F-Loss: 2.3765 | M-Loss: 1.8207 | GKL: 0.0000
# 📊 Epoch 7/100 | V@1: 40.31 | Top-5: 55.98 | F@1: 43.36 | M@1: 49.43 | V-Loss: 2.5002 | F-Loss: 2.2625 | M-Loss: 1.7372 | GKL: 0.0000
# 📊 Epoch 8/100 | V@1: 40.00 | Top-5: 57.08 | F@1: 42.84 | M@1: 48.47 | V-Loss: 2.5821 | F-Loss: 2.3580 | M-Loss: 1.8111 | GKL: 0.0000
# 📊 Epoch 9/100 | V@1: 36.33 | Top-5: 54.76 | F@1: 39.88 | M@1: 45.24 | V-Loss: 2.7142 | F-Loss: 2.4908 | M-Loss: 1.9112 | GKL: 0.0000
# 📊 Epoch 10/100 | V@1: 39.19 | Top-5: 55.42 | F@1: 41.97 | M@1: 47.80 | V-Loss: 2.5435 | F-Loss: 2.3192 | M-Loss: 1.7863 | GKL: 0.0000
# 📊 Epoch 11/100 | V@1: 40.20 | Top-5: 60.62 | F@1: 43.55 | M@1: 49.64 | V-Loss: 2.8233 | F-Loss: 2.6015 | M-Loss: 1.9841 | GKL: 0.0000
# 📊 Epoch 12/100 | V@1: 33.15 | Top-5: 48.77 | F@1: 36.42 | M@1: 41.42 | V-Loss: 2.5884 | F-Loss: 2.3669 | M-Loss: 1.8119 | GKL: 0.0000
# 📊 Epoch 13/100 | V@1: 34.07 | Top-5: 53.55 | F@1: 37.06 | M@1: 43.75 | V-Loss: 2.8623 | F-Loss: 2.6345 | M-Loss: 2.0093 | GKL: 0.0000
# 📊 Epoch 14/100 | V@1: 38.01 | Top-5: 56.61 | F@1: 41.25 | M@1: 47.09 | V-Loss: 2.7192 | F-Loss: 2.4954 | M-Loss: 1.9174 | GKL: 0.0000
# 📊 Epoch 15/100 | V@1: 37.89 | Top-5: 56.76 | F@1: 41.39 | M@1: 47.35 | V-Loss: 2.7476 | F-Loss: 2.5179 | M-Loss: 1.9285 | GKL: 0.0000
# 📊 Epoch 16/100 | V@1: 40.34 | Top-5: 60.32 | F@1: 43.45 | M@1: 48.58 | V-Loss: 2.7891 | F-Loss: 2.5583 | M-Loss: 1.9765 | GKL: 0.0000
# 📊 Epoch 17/100 | V@1: 37.70 | Top-5: 54.56 | F@1: 40.48 | M@1: 45.17 | V-Loss: 2.6215 | F-Loss: 2.4142 | M-Loss: 1.8745 | GKL: 0.0000
# 🛑 Early stopping at epoch 17 due to no improvement in variant loss.
#
# ✅ Task 17 Completed
#    ✈️ Variant Accuracy: 37.70
#    🎯 Top-5 Accuracy: 54.56
#    🏷️ Family Accuracy: 40.48
#    🏭 Manufacturer Accuracy: 45.17
#    🔻 Split Loss: 2.6215
#    🔻 Family Loss: 2.4142
#    🔻 Manufacturer Loss: 1.8745
#
#
# 🚀 Training task_18 | 6001 samples
